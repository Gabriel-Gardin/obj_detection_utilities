# %% [markdown]
# # [How to train an object detection model easy for free](https://www.dlology.com/blog/how-to-train-an-object-detection-model-easy-for-free/) | DLology Blog

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
tf.__version__
# Out:
# '1.15.2'

# %%
# Check if NVIDIA GPU is enabled
# !nvidia-smi
# Out:
# Wed Aug 26 20:31:55 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.57       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   66C    P8    11W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Mount colab notebook to google drive.
#OPÇÃO 1 ZIPAR IMAGENS DO DRIVE
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
#  Apresentacao.gslides
#  backpropagation.mp4
#  Bibliografia_LET_CV
#  BT_AtCommands
#  BTsolution
#  Classroom
# 'Colab Notebooks'
#  color_tischerFINAL
#  ESP8266
#  frames_video.zip
# 'My Drive'
#  real-time-plot-microphone-kivy-master
# 'Re-Loader.v3.0.Beta.3.E.OEMLogo-Pack.Multilingua-[WEB].rar'
#  train_data.zip
#  training_template
#  yolo_training
#  yolov3

# %% [markdown]
# ## Configs and Hyperparameters
#
# Support a variety of models, you can find more pretrained model from [Tensorflow detection model zoo: COCO-trained models](https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/detection_model_zoo.md#coco-trained-models), as well as their pipline config files in [object_detection/samples/configs/](https://github.com/tensorflow/models/tree/master/research/object_detection/samples/configs).

# %%
# If you forked the repository, you can replace the link.
repo_url = 'https://github.com/Gabriel-Gardin/object_detection_demo'

# Number of training steps.
num_steps = 10000  # 200000

# Number of evaluation steps.
num_eval_steps = 50

MODELS_CONFIG = {
    'ssd_mobilenet_v2': {
        'model_name': 'ssd_mobilenet_v2_coco_2018_03_29',
        'pipeline_file': 'ssd_mobilenet_v2_coco.config',
        'batch_size': 12
    },
    'faster_rcnn_inception_v2': {
        'model_name': 'faster_rcnn_inception_v2_coco_2018_01_28',
        'pipeline_file': 'faster_rcnn_inception_v2_pets.config',
        'batch_size': 12
    },
    'rfcn_resnet101': {
        'model_name': 'rfcn_resnet101_coco_2018_01_28',
        'pipeline_file': 'rfcn_resnet101_pets.config',
        'batch_size': 8
    }
}

# Pick the model you want to use
# Select a model in `MODELS_CONFIG`.
selected_model = 'rfcn_resnet101'

# Name of the object detection model to use.
MODEL = MODELS_CONFIG[selected_model]['model_name']

# Name of the pipline file in tensorflow object detection API.
pipeline_file = MODELS_CONFIG[selected_model]['pipeline_file']

# Training batch size fits in Colabe's Tesla K80 GPU memory for selected model.
batch_size = MODELS_CONFIG[selected_model]['batch_size']

# %% [markdown]
# ## Clone the `object_detection_demo` repository or your fork.

# %%
import os

# %cd /content

repo_dir_path = os.path.abspath(os.path.join('.', os.path.basename(repo_url)))

# !git clone {repo_url}
# %cd {repo_dir_path}
# !git pull
# Out:
# /content
# Cloning into 'object_detection_demo'...
# remote: Enumerating objects: 25, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 826 (delta 6), reused 23 (delta 5), pack-reused 801
# Receiving objects: 100% (826/826), 201.38 MiB | 47.42 MiB/s, done.
# Resolving deltas: 100% (331/331), done.
# /content/object_detection_demo
# Already up to date.

# %% [markdown]
# ## Install required packages

# %%
# %cd /content
# !git clone --quiet https://github.com/tensorflow/models.git

# !apt-get install -qq protobuf-compiler python-pil python-lxml python-tk

# !pip install -q Cython contextlib2 pillow lxml matplotlib

# !pip install -q pycocotools

# !pip install tf_slim

# %cd /content/models/research
# !protoc object_detection/protos/*.proto --python_out=.

import os
os.environ['PYTHONPATH'] += ':/content/models/research/:/content/models/research/slim/'

# !python object_detection/builders/model_builder_test.py
# Out:
# /content
# Selecting previously unselected package python-bs4.
# (Reading database ... 144556 files and directories currently installed.)
# Preparing to unpack .../0-python-bs4_4.6.0-1_all.deb ...
# Unpacking python-bs4 (4.6.0-1) ...
# Selecting previously unselected package python-pkg-resources.
# Preparing to unpack .../1-python-pkg-resources_39.0.1-2_all.deb ...
# Unpacking python-pkg-resources (39.0.1-2) ...
# Selecting previously unselected package python-chardet.
# Preparing to unpack .../2-python-chardet_3.0.4-1_all.deb ...
# Unpacking python-chardet (3.0.4-1) ...
# Selecting previously unselected package python-six.
# Preparing to unpack .../3-python-six_1.11.0-2_all.deb ...
# Unpacking python-six (1.11.0-2) ...
# Selecting previously unselected package python-webencodings.
# Preparing to unpack .../4-python-webencodings_0.5-2_all.deb ...
# Unpacking python-webencodings (0.5-2) ...
# Selecting previously unselected package python-html5lib.
# Preparing to unpack .../5-python-html5lib_0.999999999-1_all.deb ...
# Unpacking python-html5lib (0.999999999-1) ...
# Selecting previously unselected package python-lxml:amd64.
# Preparing to unpack .../6-python-lxml_4.2.1-1ubuntu0.1_amd64.deb ...
# Unpacking python-lxml:amd64 (4.2.1-1ubuntu0.1) ...
# Selecting previously unselected package python-olefile.
# Preparing to unpack .../7-python-olefile_0.45.1-1_all.deb ...
# Unpacking python-olefile (0.45.1-1) ...
# Selecting previously unselected package python-pil:amd64.
# Preparing to unpack .../8-python-pil_5.1.0-1ubuntu0.3_amd64.deb ...
# Unpacking python-pil:amd64 (5.1.0-1ubuntu0.3) ...
# Setting up python-pkg-resources (39.0.1-2) ...
# Setting up python-six (1.11.0-2) ...
# Setting up python-bs4 (4.6.0-1) ...
# Setting up python-lxml:amd64 (4.2.1-1ubuntu0.1) ...
# Setting up python-olefile (0.45.1-1) ...
# Setting up python-pil:amd64 (5.1.0-1ubuntu0.3) ...
# Setting up python-webencodings (0.5-2) ...
# Setting up python-chardet (3.0.4-1) ...
# Setting up python-html5lib (0.999999999-1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Collecting tf_slim
#   Downloading https://files.pythonhosted.org/packages/02/97/b0f4a64df018ca018cc035d44f2ef08f91e2e8aa67271f6f19633a015ff7/tf_slim-1.1.0-py2.py3-none-any.whl (352kB)
#      |████████████████████████████████| 358kB 4.8MB/s
# Requirement already satisfied: absl-py>=0.2.2 in /usr/local/lib/python3.6/dist-packages (from tf_slim) (0.8.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from absl-py>=0.2.2->tf_slim) (1.15.0)
# Installing collected packages: tf-slim
# Successfully installed tf-slim-1.1.0
# /content/models/research

# %%
#Unzip data to correct folder. 
# %cd {repo_dir_path}
# !mkdir data/images/train
#!rm -R data/images/train
# !pwd
# !ls
# !unzip /mydrive/training_template/images_1799.zip -d data/images/train/
# Out:
# /content/object_detection_demo
# /content/object_detection_demo
# data			    rename_image.py
# deploy			    requirements.txt
# generate_tfrecord.py	    resize_images.py
# LICENSE			    tensorflow_object_detection_training_colab.ipynb
# local_inference_test.ipynb  test
# local_inference_test.py     xml_to_csv.py
# README.md
# Archive:  /mydrive/training_template/images_1799.zip
#   inflating: data/images/train/0.jpg
#   inflating: data/images/train/0.xml
#   inflating: data/images/train/1.jpg
#   inflating: data/images/train/1.xml
#   inflating: data/images/train/2.jpg
#   inflating: data/images/train/2.xml
#   inflating: data/images/train/3.jpg
#   inflating: data/images/train/3.xml
#   inflating: data/images/train/4.jpg
#   inflating: data/images/train/4.xml
#   inflating: data/images/train/5.jpg
#   inflating: data/images/train/5.xml
#   inflating: data/images/train/6.jpg
#   inflating: data/images/train/6.xml
#   inflating: data/images/train/7.jpg
#   inflating: data/images/train/7.xml
#   inflating: data/images/train/8.jpg
#   inflating: data/images/train/8.xml
#   inflating: data/images/train/9.jpg
#   inflating: data/images/train/9.xml
#   inflating: data/images/train/10.jpg
#   inflating: data/images/train/10.xml
#   inflating: data/images/train/11.jpg
#   inflating: data/images/train/11.xml
#   inflating: data/images/train/12.jpg
#   inflating: data/images/train/12.xml
#   inflating: data/images/train/13.jpg
#   inflating: data/images/train/13.xml
#   inflating: data/images/train/14.jpg
#   inflating: data/images/train/14.xml
#   inflating: data/images/train/15.jpg
#   inflating: data/images/train/15.xml
#   inflating: data/images/train/16.jpg
#   inflating: data/images/train/16.xml
#   inflating: data/images/train/17.jpg
#   inflating: data/images/train/17.xml
#   inflating: data/images/train/18.jpg
#   inflating: data/images/train/18.xml
#   inflating: data/images/train/19.jpg
#   inflating: data/images/train/19.xml
#   inflating: data/images/train/20.jpg
#   inflating: data/images/train/20.xml
#   inflating: data/images/train/21.jpg
#   inflating: data/images/train/21.xml
#   inflating: data/images/train/22.jpg
#   inflating: data/images/train/22.xml
#   inflating: data/images/train/23.jpg
#   inflating: data/images/train/23.xml
#   inflating: data/images/train/24.jpg
#   inflating: data/images/train/24.xml
#   inflating: data/images/train/25.jpg
#   inflating: data/images/train/25.xml
#   inflating: data/images/train/26.jpg
#   inflating: data/images/train/26.xml
#   inflating: data/images/train/27.jpg
#   inflating: data/images/train/27.xml
#   inflating: data/images/train/28.jpg
#   inflating: data/images/train/28.xml
#   inflating: data/images/train/29.jpg
#   inflating: data/images/train/29.xml
#   inflating: data/images/train/30.jpg
#   inflating: data/images/train/30.xml
#   inflating: data/images/train/32.jpg
#   inflating: data/images/train/32.xml
#   inflating: data/images/train/33.jpg
#   inflating: data/images/train/33.xml
#   inflating: data/images/train/34.jpg
#   inflating: data/images/train/34.xml
#   inflating: data/images/train/36.jpg
#   inflating: data/images/train/36.xml
#   inflating: data/images/train/37.jpg
#   inflating: data/images/train/37.xml
#   inflating: data/images/train/38.jpg
#   inflating: data/images/train/38.xml
#   inflating: data/images/train/39.jpg
#   inflating: data/images/train/39.xml
#   inflating: data/images/train/40.jpg
#   inflating: data/images/train/40.xml
#   inflating: data/images/train/41.jpg
#   inflating: data/images/train/41.xml
#   inflating: data/images/train/42.jpg
#   inflating: data/images/train/42.xml
#   inflating: data/images/train/43.jpg
#   inflating: data/images/train/43.xml
#   inflating: data/images/train/48.jpg
#   inflating: data/images/train/48.xml
#   inflating: data/images/train/49.jpg
#   inflating: data/images/train/49.xml
#   inflating: data/images/train/50.jpg
#   inflating: data/images/train/50.xml
#   inflating: data/images/train/51.jpg
#   inflating: data/images/train/51.xml
#   inflating: data/images/train/52.jpg
#   inflating: data/images/train/52.xml
#   inflating: data/images/train/53.jpg
#   inflating: data/images/train/53.xml
#   inflating: data/images/train/54.jpg
#   inflating: data/images/train/54.xml
#   inflating: data/images/train/55.jpg
#   inflating: data/images/train/55.xml
#   inflating: data/images/train/56.jpg
#   inflating: data/images/train/56.xml
#   inflating: data/images/train/57.jpg
#   inflating: data/images/train/57.xml
#   inflating: data/images/train/58.jpg
#   inflating: data/images/train/58.xml
#   inflating: data/images/train/59.jpg
#   inflating: data/images/train/59.xml
#   inflating: data/images/train/60.jpg
#   inflating: data/images/train/60.xml
#   inflating: data/images/train/61.jpg
#   inflating: data/images/train/61.xml
#   inflating: data/images/train/62.jpg
#   inflating: data/images/train/62.xml
#   inflating: data/images/train/63.jpg
#   inflating: data/images/train/63.xml
#   inflating: data/images/train/64.jpg
#   inflating: data/images/train/64.xml
#   inflating: data/images/train/65.jpg
#   inflating: data/images/train/65.xml
#   inflating: data/images/train/66.jpg
#   inflating: data/images/train/66.xml
#   inflating: data/images/train/67.jpg
#   inflating: data/images/train/67.xml
#   inflating: data/images/train/68.jpg
#   inflating: data/images/train/68.xml
#   inflating: data/images/train/69.jpg
#   inflating: data/images/train/69.xml
#   inflating: data/images/train/70.jpg
#   inflating: data/images/train/70.xml
#   inflating: data/images/train/71.jpg
#   inflating: data/images/train/71.xml
#   inflating: data/images/train/73.jpg
#   inflating: data/images/train/73.xml
#   inflating: data/images/train/74.jpg
#   inflating: data/images/train/74.xml
#   inflating: data/images/train/76.jpg
#   inflating: data/images/train/76.xml
#   inflating: data/images/train/77.jpg
#   inflating: data/images/train/77.xml
#   inflating: data/images/train/79.jpg
#   inflating: data/images/train/79.xml
#   inflating: data/images/train/80.jpg
#   inflating: data/images/train/80.xml
#   inflating: data/images/train/81.jpg
#   inflating: data/images/train/81.xml
#   inflating: data/images/train/82.jpg
#   inflating: data/images/train/82.xml
#   inflating: data/images/train/83.jpg
#   inflating: data/images/train/83.xml
#   inflating: data/images/train/84.jpg
#   inflating: data/images/train/84.xml
#   inflating: data/images/train/85.jpg
#   inflating: data/images/train/85.xml
#   inflating: data/images/train/86.jpg
#   inflating: data/images/train/86.xml
#   inflating: data/images/train/87.jpg
#   inflating: data/images/train/87.xml
#   inflating: data/images/train/88.jpg
#   inflating: data/images/train/88.xml
#   inflating: data/images/train/89.jpg
#   inflating: data/images/train/89.xml
#   inflating: data/images/train/90.jpg
#   inflating: data/images/train/90.xml
#   inflating: data/images/train/91.jpg
#   inflating: data/images/train/91.xml
#   inflating: data/images/train/92.jpg
#   inflating: data/images/train/92.xml
#   inflating: data/images/train/93.jpg
#   inflating: data/images/train/93.xml
#   inflating: data/images/train/95.jpg
#   inflating: data/images/train/95.xml
#   inflating: data/images/train/97.jpg
#   inflating: data/images/train/97.xml
#   inflating: data/images/train/98.jpg
#   inflating: data/images/train/98.xml
#   inflating: data/images/train/99.jpg
#   inflating: data/images/train/99.xml
#   inflating: data/images/train/101.jpg
#   inflating: data/images/train/101.xml
#   inflating: data/images/train/102.jpg
#   inflating: data/images/train/102.xml
#   inflating: data/images/train/103.jpg
#   inflating: data/images/train/103.xml
#   inflating: data/images/train/104.jpg
#   inflating: data/images/train/104.xml
#   inflating: data/images/train/105.jpg
#   inflating: data/images/train/105.xml
#   inflating: data/images/train/106.jpg
#   inflating: data/images/train/106.xml
#   inflating: data/images/train/107.jpg
#   inflating: data/images/train/107.xml
#   inflating: data/images/train/108.jpg
#   inflating: data/images/train/108.xml
#   inflating: data/images/train/109.jpg
#   inflating: data/images/train/109.xml
#   inflating: data/images/train/110.jpg
#   inflating: data/images/train/110.xml
#   inflating: data/images/train/111.jpg
#   inflating: data/images/train/111.xml
#   inflating: data/images/train/112.jpg
#   inflating: data/images/train/112.xml
#   inflating: data/images/train/113.jpg
#   inflating: data/images/train/113.xml
#   inflating: data/images/train/114.jpg
#   inflating: data/images/train/114.xml
#   inflating: data/images/train/115.jpg
#   inflating: data/images/train/115.xml
#   inflating: data/images/train/116.jpg
#   inflating: data/images/train/116.xml
#   inflating: data/images/train/117.jpg
#   inflating: data/images/train/117.xml
#   inflating: data/images/train/118.jpg
#   inflating: data/images/train/118.xml
#   inflating: data/images/train/119.jpg
#   inflating: data/images/train/119.xml
#   inflating: data/images/train/121.jpg
#   inflating: data/images/train/121.xml
#   inflating: data/images/train/122.jpg
#   inflating: data/images/train/122.xml
#   inflating: data/images/train/124.jpg
#   inflating: data/images/train/124.xml
#   inflating: data/images/train/125.jpg
#   inflating: data/images/train/125.xml
#   inflating: data/images/train/126.jpg
#   inflating: data/images/train/126.xml
#   inflating: data/images/train/127.jpg
#   inflating: data/images/train/127.xml
#   inflating: data/images/train/128.jpg
#   inflating: data/images/train/128.xml
#   inflating: data/images/train/129.jpg
#   inflating: data/images/train/129.xml
#   inflating: data/images/train/130.jpg
#   inflating: data/images/train/130.xml
#   inflating: data/images/train/131.jpg
#   inflating: data/images/train/131.xml
#   inflating: data/images/train/132.jpg
#   inflating: data/images/train/132.xml
#   inflating: data/images/train/133.jpg
#   inflating: data/images/train/133.xml
#   inflating: data/images/train/134.jpg
#   inflating: data/images/train/134.xml
#   inflating: data/images/train/135.jpg
#   inflating: data/images/train/135.xml
#   inflating: data/images/train/136.jpg
#   inflating: data/images/train/136.xml
#   inflating: data/images/train/139.jpg
#   inflating: data/images/train/139.xml
#   inflating: data/images/train/140.jpg
#   inflating: data/images/train/140.xml
#   inflating: data/images/train/141.jpg
#   inflating: data/images/train/141.xml
#   inflating: data/images/train/143.jpg
#   inflating: data/images/train/143.xml
#   inflating: data/images/train/144.jpg
#   inflating: data/images/train/144.xml
#   inflating: data/images/train/145.jpg
#   inflating: data/images/train/145.xml
#   inflating: data/images/train/146.jpg
#   inflating: data/images/train/146.xml
#   inflating: data/images/train/149.jpg
#   inflating: data/images/train/149.xml
#   inflating: data/images/train/150.jpg
#   inflating: data/images/train/150.xml
#   inflating: data/images/train/151.jpg
#   inflating: data/images/train/151.xml
#   inflating: data/images/train/153.jpg
#   inflating: data/images/train/153.xml
#   inflating: data/images/train/154.jpg
#   inflating: data/images/train/154.xml
#   inflating: data/images/train/155.jpg
#   inflating: data/images/train/155.xml
#   inflating: data/images/train/156.jpg
#   inflating: data/images/train/156.xml
#   inflating: data/images/train/157.jpg
#   inflating: data/images/train/157.xml
#   inflating: data/images/train/158.jpg
#   inflating: data/images/train/158.xml
#   inflating: data/images/train/159.jpg
#   inflating: data/images/train/159.xml
#   inflating: data/images/train/160.jpg
#   inflating: data/images/train/160.xml
#   inflating: data/images/train/161.jpg
#   inflating: data/images/train/161.xml
#   inflating: data/images/train/163.jpg
#   inflating: data/images/train/163.xml
#   inflating: data/images/train/164.jpg
#   inflating: data/images/train/164.xml
#   inflating: data/images/train/165.jpg
#   inflating: data/images/train/165.xml
#   inflating: data/images/train/166.jpg
#   inflating: data/images/train/166.xml
#   inflating: data/images/train/167.jpg
#   inflating: data/images/train/167.xml
#   inflating: data/images/train/168.jpg
#   inflating: data/images/train/168.xml
#   inflating: data/images/train/169.jpg
#   inflating: data/images/train/169.xml
#   inflating: data/images/train/170.jpg
#   inflating: data/images/train/170.xml
#   inflating: data/images/train/171.jpg
#   inflating: data/images/train/171.xml
#   inflating: data/images/train/172.jpg
#   inflating: data/images/train/172.xml
#   inflating: data/images/train/173.jpg
#   inflating: data/images/train/173.xml
#   inflating: data/images/train/174.jpg
#   inflating: data/images/train/174.xml
#   inflating: data/images/train/175.jpg
#   inflating: data/images/train/175.xml
#   inflating: data/images/train/176.jpg
#   inflating: data/images/train/176.xml
#   inflating: data/images/train/177.jpg
#   inflating: data/images/train/177.xml
#   inflating: data/images/train/178.jpg
#   inflating: data/images/train/178.xml
#   inflating: data/images/train/179.jpg
#   inflating: data/images/train/179.xml
#   inflating: data/images/train/180.jpg
#   inflating: data/images/train/180.xml
#   inflating: data/images/train/181.jpg
#   inflating: data/images/train/181.xml
#   inflating: data/images/train/182.jpg
#   inflating: data/images/train/182.xml
#   inflating: data/images/train/183.jpg
#   inflating: data/images/train/183.xml
#   inflating: data/images/train/184.jpg
#   inflating: data/images/train/184.xml
#   inflating: data/images/train/185.jpg
#   inflating: data/images/train/185.xml
#   inflating: data/images/train/187.jpg
#   inflating: data/images/train/187.xml
#   inflating: data/images/train/189.jpg
#   inflating: data/images/train/189.xml
#   inflating: data/images/train/190.jpg
#   inflating: data/images/train/190.xml
#   inflating: data/images/train/191.jpg
#   inflating: data/images/train/191.xml
#   inflating: data/images/train/192.jpg
#   inflating: data/images/train/192.xml
#   inflating: data/images/train/193.jpg
#   inflating: data/images/train/193.xml
#   inflating: data/images/train/194.jpg
#   inflating: data/images/train/194.xml
#   inflating: data/images/train/195.jpg
#   inflating: data/images/train/195.xml
#   inflating: data/images/train/196.jpg
#   inflating: data/images/train/196.xml
#   inflating: data/images/train/198.jpg
#   inflating: data/images/train/198.xml
#   inflating: data/images/train/199.jpg
#   inflating: data/images/train/199.xml
#   inflating: data/images/train/200.jpg
#   inflating: data/images/train/200.xml
#   inflating: data/images/train/201.jpg
#   inflating: data/images/train/201.xml
#   inflating: data/images/train/202.jpg
#   inflating: data/images/train/202.xml
#   inflating: data/images/train/203.jpg
#   inflating: data/images/train/203.xml
#   inflating: data/images/train/204.jpg
#   inflating: data/images/train/204.xml
#   inflating: data/images/train/205.jpg
#   inflating: data/images/train/205.xml
#   inflating: data/images/train/206.jpg
#   inflating: data/images/train/206.xml
#   inflating: data/images/train/207.jpg
#   inflating: data/images/train/207.xml
#   inflating: data/images/train/209.jpg
#   inflating: data/images/train/209.xml
#   inflating: data/images/train/210.jpg
#   inflating: data/images/train/210.xml
#   inflating: data/images/train/211.jpg
#   inflating: data/images/train/211.xml
#   inflating: data/images/train/212.jpg
#   inflating: data/images/train/212.xml
#   inflating: data/images/train/213.jpg
#   inflating: data/images/train/213.xml
#   inflating: data/images/train/214.jpg
#   inflating: data/images/train/214.xml
#   inflating: data/images/train/215.jpg
#   inflating: data/images/train/215.xml
#   inflating: data/images/train/216.jpg
#   inflating: data/images/train/216.xml
#   inflating: data/images/train/217.jpg
#   inflating: data/images/train/217.xml
#   inflating: data/images/train/219.jpg
#   inflating: data/images/train/219.xml
#   inflating: data/images/train/220.jpg
#   inflating: data/images/train/220.xml
#   inflating: data/images/train/221.jpg
#   inflating: data/images/train/221.xml
#   inflating: data/images/train/222.jpg
#   inflating: data/images/train/222.xml
#   inflating: data/images/train/223.jpg
#   inflating: data/images/train/223.xml
#   inflating: data/images/train/224.jpg
#   inflating: data/images/train/224.xml
#   inflating: data/images/train/225.jpg
#   inflating: data/images/train/225.xml
#   inflating: data/images/train/226.jpg
#   inflating: data/images/train/226.xml
#   inflating: data/images/train/227.jpg
#   inflating: data/images/train/227.xml
#   inflating: data/images/train/229.jpg
#   inflating: data/images/train/229.xml
#   inflating: data/images/train/230.jpg
#   inflating: data/images/train/230.xml
#   inflating: data/images/train/232.jpg
#   inflating: data/images/train/232.xml
#   inflating: data/images/train/233.jpg
#   inflating: data/images/train/233.xml
#   inflating: data/images/train/234.jpg
#   inflating: data/images/train/234.xml
#   inflating: data/images/train/235.jpg
#   inflating: data/images/train/235.xml
#   inflating: data/images/train/236.jpg
#   inflating: data/images/train/236.xml
#   inflating: data/images/train/237.jpg
#   inflating: data/images/train/237.xml
#   inflating: data/images/train/241.jpg
#   inflating: data/images/train/241.xml
#   inflating: data/images/train/244.jpg
#   inflating: data/images/train/244.xml
#   inflating: data/images/train/245.jpg
#   inflating: data/images/train/245.xml
#   inflating: data/images/train/246.jpg
#   inflating: data/images/train/246.xml
#   inflating: data/images/train/247.jpg
#   inflating: data/images/train/247.xml
#   inflating: data/images/train/249.jpg
#   inflating: data/images/train/249.xml
#   inflating: data/images/train/250.jpg
#   inflating: data/images/train/250.xml
#   inflating: data/images/train/251.jpg
#   inflating: data/images/train/251.xml
#   inflating: data/images/train/252.jpg
#   inflating: data/images/train/252.xml
#   inflating: data/images/train/253.jpg
#   inflating: data/images/train/253.xml
#   inflating: data/images/train/254.jpg
#   inflating: data/images/train/254.xml
#   inflating: data/images/train/255.jpg
#   inflating: data/images/train/255.xml
#   inflating: data/images/train/256.jpg
#   inflating: data/images/train/256.xml
#   inflating: data/images/train/258.jpg
#   inflating: data/images/train/258.xml
#   inflating: data/images/train/259.jpg
#   inflating: data/images/train/259.xml
#   inflating: data/images/train/260.jpg
#   inflating: data/images/train/260.xml
#   inflating: data/images/train/261.jpg
#   inflating: data/images/train/261.xml
#   inflating: data/images/train/262.jpg
#   inflating: data/images/train/262.xml
#   inflating: data/images/train/263.jpg
#   inflating: data/images/train/263.xml
#   inflating: data/images/train/264.jpg
#   inflating: data/images/train/264.xml
#   inflating: data/images/train/265.jpg
#   inflating: data/images/train/265.xml
#   inflating: data/images/train/266.jpg
#   inflating: data/images/train/266.xml
#   inflating: data/images/train/267.jpg
#   inflating: data/images/train/267.xml
#   inflating: data/images/train/268.jpg
#   inflating: data/images/train/268.xml
#   inflating: data/images/train/269.jpg
#   inflating: data/images/train/269.xml
#   inflating: data/images/train/270.jpg
#   inflating: data/images/train/270.xml
#   inflating: data/images/train/271.jpg
#   inflating: data/images/train/271.xml
#   inflating: data/images/train/272.jpg
#   inflating: data/images/train/272.xml
#   inflating: data/images/train/273.jpg
#   inflating: data/images/train/273.xml
#   inflating: data/images/train/274.jpg
#   inflating: data/images/train/274.xml
#   inflating: data/images/train/275.jpg
#   inflating: data/images/train/275.xml
#   inflating: data/images/train/276.jpg
#   inflating: data/images/train/276.xml
#   inflating: data/images/train/277.jpg
#   inflating: data/images/train/277.xml
#   inflating: data/images/train/278.jpg
#   inflating: data/images/train/278.xml
#   inflating: data/images/train/279.jpg
#   inflating: data/images/train/279.xml
#   inflating: data/images/train/280.jpg
#   inflating: data/images/train/280.xml
#   inflating: data/images/train/281.jpg
#   inflating: data/images/train/281.xml
#   inflating: data/images/train/282.jpg
#   inflating: data/images/train/282.xml
#   inflating: data/images/train/283.jpg
#   inflating: data/images/train/283.xml
#   inflating: data/images/train/284.jpg
#   inflating: data/images/train/284.xml
#   inflating: data/images/train/285.jpg
#   inflating: data/images/train/285.xml
#   inflating: data/images/train/286.jpg
#   inflating: data/images/train/286.xml
#   inflating: data/images/train/287.jpg
#   inflating: data/images/train/287.xml
#   inflating: data/images/train/290.jpg
#   inflating: data/images/train/290.xml
#   inflating: data/images/train/291.jpg
#   inflating: data/images/train/291.xml
#   inflating: data/images/train/292.jpg
#   inflating: data/images/train/292.xml
#   inflating: data/images/train/293.jpg
#   inflating: data/images/train/293.xml
#   inflating: data/images/train/294.jpg
#   inflating: data/images/train/294.xml
#   inflating: data/images/train/295.jpg
#   inflating: data/images/train/295.xml
#   inflating: data/images/train/296.jpg
#   inflating: data/images/train/296.xml
#   inflating: data/images/train/297.jpg
#   inflating: data/images/train/297.xml
#   inflating: data/images/train/299.jpg
#   inflating: data/images/train/299.xml
#   inflating: data/images/train/300.jpg
#   inflating: data/images/train/300.xml
#   inflating: data/images/train/301.jpg
#   inflating: data/images/train/301.xml
#   inflating: data/images/train/302.jpg
#   inflating: data/images/train/302.xml
#   inflating: data/images/train/303.jpg
#   inflating: data/images/train/303.xml
#   inflating: data/images/train/305.jpg
#   inflating: data/images/train/305.xml
#   inflating: data/images/train/307.jpg
#   inflating: data/images/train/307.xml
#   inflating: data/images/train/308.jpg
#   inflating: data/images/train/308.xml
#   inflating: data/images/train/309.jpg
#   inflating: data/images/train/309.xml
#   inflating: data/images/train/310.jpg
#   inflating: data/images/train/310.xml
#   inflating: data/images/train/311.jpg
#   inflating: data/images/train/311.xml
#   inflating: data/images/train/314.jpg
#   inflating: data/images/train/314.xml
#   inflating: data/images/train/315.jpg
#   inflating: data/images/train/315.xml
#   inflating: data/images/train/316.jpg
#   inflating: data/images/train/316.xml
#   inflating: data/images/train/317.jpg
#   inflating: data/images/train/317.xml
#   inflating: data/images/train/318.jpg
#   inflating: data/images/train/318.xml
#   inflating: data/images/train/319.jpg
#   inflating: data/images/train/319.xml
#   inflating: data/images/train/320.jpg
#   inflating: data/images/train/320.xml
#   inflating: data/images/train/321.jpg
#   inflating: data/images/train/321.xml
#   inflating: data/images/train/322.jpg
#   inflating: data/images/train/322.xml
#   inflating: data/images/train/323.jpg
#   inflating: data/images/train/323.xml
#   inflating: data/images/train/324.jpg
#   inflating: data/images/train/324.xml
#   inflating: data/images/train/325.jpg
#   inflating: data/images/train/325.xml
#   inflating: data/images/train/326.jpg
#   inflating: data/images/train/326.xml
#   inflating: data/images/train/327.jpg
#   inflating: data/images/train/327.xml
#   inflating: data/images/train/328.jpg
#   inflating: data/images/train/328.xml
#   inflating: data/images/train/329.jpg
#   inflating: data/images/train/329.xml
#   inflating: data/images/train/330.jpg
#   inflating: data/images/train/330.xml
#   inflating: data/images/train/331.jpg
#   inflating: data/images/train/331.xml
#   inflating: data/images/train/332.jpg
#   inflating: data/images/train/332.xml
#   inflating: data/images/train/334.jpg
#   inflating: data/images/train/334.xml
#   inflating: data/images/train/336.jpg
#   inflating: data/images/train/336.xml
#   inflating: data/images/train/337.jpg
#   inflating: data/images/train/337.xml
#   inflating: data/images/train/338.jpg
#   inflating: data/images/train/338.xml
#   inflating: data/images/train/339.jpg
#   inflating: data/images/train/339.xml
#   inflating: data/images/train/340.jpg
#   inflating: data/images/train/340.xml
#   inflating: data/images/train/341.jpg
#   inflating: data/images/train/341.xml
#   inflating: data/images/train/344.jpg
#   inflating: data/images/train/344.xml
#   inflating: data/images/train/345.jpg
#   inflating: data/images/train/345.xml
#   inflating: data/images/train/346.jpg
#   inflating: data/images/train/346.xml
#   inflating: data/images/train/347.jpg
#   inflating: data/images/train/347.xml
#   inflating: data/images/train/348.jpg
#   inflating: data/images/train/348.xml
#   inflating: data/images/train/349.jpg
#   inflating: data/images/train/349.xml
#   inflating: data/images/train/350.jpg
#   inflating: data/images/train/350.xml
#   inflating: data/images/train/351.jpg
#   inflating: data/images/train/351.xml
#   inflating: data/images/train/352.jpg
#   inflating: data/images/train/352.xml
#   inflating: data/images/train/353.jpg
#   inflating: data/images/train/353.xml
#   inflating: data/images/train/354.jpg
#   inflating: data/images/train/354.xml
#   inflating: data/images/train/356.jpg
#   inflating: data/images/train/356.xml
#   inflating: data/images/train/357.jpg
#   inflating: data/images/train/357.xml
#   inflating: data/images/train/358.jpg
#   inflating: data/images/train/358.xml
#   inflating: data/images/train/359.jpg
#   inflating: data/images/train/359.xml
#   inflating: data/images/train/360.jpg
#   inflating: data/images/train/360.xml
#   inflating: data/images/train/362.jpg
#   inflating: data/images/train/362.xml
#   inflating: data/images/train/363.jpg
#   inflating: data/images/train/363.xml
#   inflating: data/images/train/366.jpg
#   inflating: data/images/train/366.xml
#   inflating: data/images/train/367.jpg
#   inflating: data/images/train/367.xml
#   inflating: data/images/train/371.jpg
#   inflating: data/images/train/371.xml
#   inflating: data/images/train/373.jpg
#   inflating: data/images/train/373.xml
#   inflating: data/images/train/374.jpg
#   inflating: data/images/train/374.xml
#   inflating: data/images/train/375.jpg
#   inflating: data/images/train/375.xml
#   inflating: data/images/train/376.jpg
#   inflating: data/images/train/376.xml
#   inflating: data/images/train/377.jpg
#   inflating: data/images/train/377.xml
#   inflating: data/images/train/378.jpg
#   inflating: data/images/train/378.xml
#   inflating: data/images/train/379.jpg
#   inflating: data/images/train/379.xml
#   inflating: data/images/train/380.jpg
#   inflating: data/images/train/380.xml
#   inflating: data/images/train/382.jpg
#   inflating: data/images/train/382.xml
#   inflating: data/images/train/383.jpg
#   inflating: data/images/train/383.xml
#   inflating: data/images/train/384.jpg
#   inflating: data/images/train/384.xml
#   inflating: data/images/train/386.jpg
#   inflating: data/images/train/386.xml
#   inflating: data/images/train/388.jpg
#   inflating: data/images/train/388.xml
#   inflating: data/images/train/391.jpg
#   inflating: data/images/train/391.xml
#   inflating: data/images/train/392.jpg
#   inflating: data/images/train/392.xml
#   inflating: data/images/train/393.jpg
#   inflating: data/images/train/393.xml
#   inflating: data/images/train/394.jpg
#   inflating: data/images/train/394.xml
#   inflating: data/images/train/395.jpg
#   inflating: data/images/train/395.xml
#   inflating: data/images/train/396.jpg
#   inflating: data/images/train/396.xml
#   inflating: data/images/train/397.jpg
#   inflating: data/images/train/397.xml
#   inflating: data/images/train/399.jpg
#   inflating: data/images/train/399.xml
#   inflating: data/images/train/401.jpg
#   inflating: data/images/train/401.xml
#   inflating: data/images/train/402.jpg
#   inflating: data/images/train/402.xml
#   inflating: data/images/train/403.jpg
#   inflating: data/images/train/403.xml
#   inflating: data/images/train/404.jpg
#   inflating: data/images/train/404.xml
#   inflating: data/images/train/407.jpg
#   inflating: data/images/train/407.xml
#   inflating: data/images/train/408.jpg
#   inflating: data/images/train/408.xml
#   inflating: data/images/train/409.jpg
#   inflating: data/images/train/409.xml
#   inflating: data/images/train/410.jpg
#   inflating: data/images/train/410.xml
#   inflating: data/images/train/411.jpg
#   inflating: data/images/train/411.xml
#   inflating: data/images/train/412.jpg
#   inflating: data/images/train/412.xml
#   inflating: data/images/train/413.jpg
#   inflating: data/images/train/413.xml
#   inflating: data/images/train/414.jpg
#   inflating: data/images/train/414.xml
#   inflating: data/images/train/415.jpg
#   inflating: data/images/train/415.xml
#   inflating: data/images/train/417.jpg
#   inflating: data/images/train/417.xml
#   inflating: data/images/train/418.jpg
#   inflating: data/images/train/418.xml
#   inflating: data/images/train/419.jpg
#   inflating: data/images/train/419.xml
#   inflating: data/images/train/421.jpg
#   inflating: data/images/train/421.xml
#   inflating: data/images/train/422.jpg
#   inflating: data/images/train/422.xml
#   inflating: data/images/train/423.jpg
#   inflating: data/images/train/423.xml
#   inflating: data/images/train/424.jpg
#   inflating: data/images/train/424.xml
#   inflating: data/images/train/425.jpg
#   inflating: data/images/train/425.xml
#   inflating: data/images/train/426.jpg
#   inflating: data/images/train/426.xml
#   inflating: data/images/train/428.jpg
#   inflating: data/images/train/428.xml
#   inflating: data/images/train/429.jpg
#   inflating: data/images/train/429.xml
#   inflating: data/images/train/430.jpg
#   inflating: data/images/train/430.xml
#   inflating: data/images/train/431.jpg
#   inflating: data/images/train/431.xml
#   inflating: data/images/train/432.jpg
#   inflating: data/images/train/432.xml
#   inflating: data/images/train/435.jpg
#   inflating: data/images/train/435.xml
#   inflating: data/images/train/436.jpg
#   inflating: data/images/train/436.xml
#   inflating: data/images/train/437.jpg
#   inflating: data/images/train/437.xml
#   inflating: data/images/train/438.jpg
#   inflating: data/images/train/438.xml
#   inflating: data/images/train/439.jpg
#   inflating: data/images/train/439.xml
#   inflating: data/images/train/440.jpg
#   inflating: data/images/train/440.xml
#   inflating: data/images/train/442.jpg
#   inflating: data/images/train/442.xml
#   inflating: data/images/train/443.jpg
#   inflating: data/images/train/443.xml
#   inflating: data/images/train/444.jpg
#   inflating: data/images/train/444.xml
#   inflating: data/images/train/445.jpg
#   inflating: data/images/train/445.xml
#   inflating: data/images/train/446.jpg
#   inflating: data/images/train/446.xml
#   inflating: data/images/train/447.jpg
#   inflating: data/images/train/447.xml
#   inflating: data/images/train/448.jpg
#   inflating: data/images/train/448.xml
#   inflating: data/images/train/450.jpg
#   inflating: data/images/train/450.xml
#   inflating: data/images/train/451.jpg
#   inflating: data/images/train/451.xml
#   inflating: data/images/train/453.jpg
#   inflating: data/images/train/453.xml
#   inflating: data/images/train/454.jpg
#   inflating: data/images/train/454.xml
#   inflating: data/images/train/455.jpg
#   inflating: data/images/train/455.xml
#   inflating: data/images/train/456.jpg
#   inflating: data/images/train/456.xml
#   inflating: data/images/train/457.jpg
#   inflating: data/images/train/457.xml
#   inflating: data/images/train/458.jpg
#   inflating: data/images/train/458.xml
#   inflating: data/images/train/461.jpg
#   inflating: data/images/train/461.xml
#   inflating: data/images/train/462.jpg
#   inflating: data/images/train/462.xml
#   inflating: data/images/train/463.jpg
#   inflating: data/images/train/463.xml
#   inflating: data/images/train/464.jpg
#   inflating: data/images/train/464.xml
#   inflating: data/images/train/465.jpg
#   inflating: data/images/train/465.xml
#   inflating: data/images/train/467.jpg
#   inflating: data/images/train/467.xml
#   inflating: data/images/train/468.jpg
#   inflating: data/images/train/468.xml
#   inflating: data/images/train/469.jpg
#   inflating: data/images/train/469.xml
#   inflating: data/images/train/470.jpg
#   inflating: data/images/train/470.xml
#   inflating: data/images/train/471.jpg
#   inflating: data/images/train/471.xml
#   inflating: data/images/train/472.jpg
#   inflating: data/images/train/472.xml
#   inflating: data/images/train/473.jpg
#   inflating: data/images/train/473.xml
#   inflating: data/images/train/474.jpg
#   inflating: data/images/train/474.xml
#   inflating: data/images/train/475.jpg
#   inflating: data/images/train/475.xml
#   inflating: data/images/train/476.jpg
#   inflating: data/images/train/476.xml
#   inflating: data/images/train/477.jpg
#   inflating: data/images/train/477.xml
#   inflating: data/images/train/478.jpg
#   inflating: data/images/train/478.xml
#   inflating: data/images/train/479.jpg
#   inflating: data/images/train/479.xml
#   inflating: data/images/train/480.jpg
#   inflating: data/images/train/480.xml
#   inflating: data/images/train/482.jpg
#   inflating: data/images/train/482.xml
#   inflating: data/images/train/483.jpg
#   inflating: data/images/train/483.xml
#   inflating: data/images/train/484.jpg
#   inflating: data/images/train/484.xml
#   inflating: data/images/train/485.jpg
#   inflating: data/images/train/485.xml
#   inflating: data/images/train/486.jpg
#   inflating: data/images/train/486.xml
#   inflating: data/images/train/487.jpg
#   inflating: data/images/train/487.xml
#   inflating: data/images/train/489.jpg
#   inflating: data/images/train/489.xml
#   inflating: data/images/train/490.jpg
#   inflating: data/images/train/490.xml
#   inflating: data/images/train/492.jpg
#   inflating: data/images/train/492.xml
#   inflating: data/images/train/493.jpg
#   inflating: data/images/train/493.xml
#   inflating: data/images/train/494.jpg
#   inflating: data/images/train/494.xml
#   inflating: data/images/train/495.jpg
#   inflating: data/images/train/495.xml
#   inflating: data/images/train/496.jpg
#   inflating: data/images/train/496.xml
#   inflating: data/images/train/497.jpg
#   inflating: data/images/train/497.xml
#   inflating: data/images/train/498.jpg
#   inflating: data/images/train/498.xml
#   inflating: data/images/train/499.jpg
#   inflating: data/images/train/499.xml
#   inflating: data/images/train/501.jpg
#   inflating: data/images/train/501.xml
#   inflating: data/images/train/502.jpg
#   inflating: data/images/train/502.xml
#   inflating: data/images/train/503.jpg
#   inflating: data/images/train/503.xml
#   inflating: data/images/train/505.jpg
#   inflating: data/images/train/505.xml
#   inflating: data/images/train/506.jpg
#   inflating: data/images/train/506.xml
#   inflating: data/images/train/507.jpg
#   inflating: data/images/train/507.xml
#   inflating: data/images/train/508.jpg
#   inflating: data/images/train/508.xml
#   inflating: data/images/train/509.jpg
#   inflating: data/images/train/509.xml
#   inflating: data/images/train/510.jpg
#   inflating: data/images/train/510.xml
#   inflating: data/images/train/511.jpg
#   inflating: data/images/train/511.xml
#   inflating: data/images/train/512.jpg
#   inflating: data/images/train/512.xml
#   inflating: data/images/train/513.jpg
#   inflating: data/images/train/513.xml
#   inflating: data/images/train/514.jpg
#   inflating: data/images/train/514.xml
#   inflating: data/images/train/515.jpg
#   inflating: data/images/train/515.xml
#   inflating: data/images/train/516.jpg
#   inflating: data/images/train/516.xml
#   inflating: data/images/train/517.jpg
#   inflating: data/images/train/517.xml
#   inflating: data/images/train/518.jpg
#   inflating: data/images/train/518.xml
#   inflating: data/images/train/519.jpg
#   inflating: data/images/train/519.xml
#   inflating: data/images/train/520.jpg
#   inflating: data/images/train/520.xml
#   inflating: data/images/train/522.jpg
#   inflating: data/images/train/522.xml
#   inflating: data/images/train/523.jpg
#   inflating: data/images/train/523.xml
#   inflating: data/images/train/524.jpg
#   inflating: data/images/train/524.xml
#   inflating: data/images/train/525.jpg
#   inflating: data/images/train/525.xml
#   inflating: data/images/train/526.jpg
#   inflating: data/images/train/526.xml
#   inflating: data/images/train/528.jpg
#   inflating: data/images/train/528.xml
#   inflating: data/images/train/530.jpg
#   inflating: data/images/train/530.xml
#   inflating: data/images/train/531.jpg
#   inflating: data/images/train/531.xml
#   inflating: data/images/train/532.jpg
#   inflating: data/images/train/532.xml
#   inflating: data/images/train/534.jpg
#   inflating: data/images/train/534.xml
#   inflating: data/images/train/536.jpg
#   inflating: data/images/train/536.xml
#   inflating: data/images/train/538.jpg
#   inflating: data/images/train/538.xml
#   inflating: data/images/train/539.jpg
#   inflating: data/images/train/539.xml
#   inflating: data/images/train/540.jpg
#   inflating: data/images/train/540.xml
#   inflating: data/images/train/541.jpg
#   inflating: data/images/train/541.xml
#   inflating: data/images/train/542.jpg
#   inflating: data/images/train/542.xml
#   inflating: data/images/train/543.jpg
#   inflating: data/images/train/543.xml
#   inflating: data/images/train/544.jpg
#   inflating: data/images/train/544.xml
#   inflating: data/images/train/546.jpg
#   inflating: data/images/train/546.xml
#   inflating: data/images/train/548.jpg
#   inflating: data/images/train/548.xml
#   inflating: data/images/train/549.jpg
#   inflating: data/images/train/549.xml
#   inflating: data/images/train/550.jpg
#   inflating: data/images/train/550.xml
#   inflating: data/images/train/551.jpg
#   inflating: data/images/train/551.xml
#   inflating: data/images/train/552.jpg
#   inflating: data/images/train/552.xml
#   inflating: data/images/train/553.jpg
#   inflating: data/images/train/553.xml
#   inflating: data/images/train/554.jpg
#   inflating: data/images/train/554.xml
#   inflating: data/images/train/555.jpg
#   inflating: data/images/train/555.xml
#   inflating: data/images/train/556.jpg
#   inflating: data/images/train/556.xml
#   inflating: data/images/train/557.jpg
#   inflating: data/images/train/557.xml
#   inflating: data/images/train/558.jpg
#   inflating: data/images/train/558.xml
#   inflating: data/images/train/559.jpg
#   inflating: data/images/train/559.xml
#   inflating: data/images/train/560.jpg
#   inflating: data/images/train/560.xml
#   inflating: data/images/train/561.jpg
#   inflating: data/images/train/561.xml
#   inflating: data/images/train/562.jpg
#   inflating: data/images/train/562.xml
#   inflating: data/images/train/564.jpg
#   inflating: data/images/train/564.xml
#   inflating: data/images/train/566.jpg
#   inflating: data/images/train/566.xml
#   inflating: data/images/train/567.jpg
#   inflating: data/images/train/567.xml
#   inflating: data/images/train/568.jpg
#   inflating: data/images/train/568.xml
#   inflating: data/images/train/571.jpg
#   inflating: data/images/train/571.xml
#   inflating: data/images/train/573.jpg
#   inflating: data/images/train/573.xml
#   inflating: data/images/train/574.jpg
#   inflating: data/images/train/574.xml
#   inflating: data/images/train/575.jpg
#   inflating: data/images/train/575.xml
#   inflating: data/images/train/576.jpg
#   inflating: data/images/train/576.xml
#   inflating: data/images/train/578.jpg
#   inflating: data/images/train/578.xml
#   inflating: data/images/train/580.jpg
#   inflating: data/images/train/580.xml
#   inflating: data/images/train/581.jpg
#   inflating: data/images/train/581.xml
#   inflating: data/images/train/582.jpg
#   inflating: data/images/train/582.xml
#   inflating: data/images/train/583.jpg
#   inflating: data/images/train/583.xml
#   inflating: data/images/train/584.jpg
#   inflating: data/images/train/584.xml
#   inflating: data/images/train/585.jpg
#   inflating: data/images/train/585.xml
#   inflating: data/images/train/586.jpg
#   inflating: data/images/train/586.xml
#   inflating: data/images/train/588.jpg
#   inflating: data/images/train/588.xml
#   inflating: data/images/train/589.jpg
#   inflating: data/images/train/589.xml
#   inflating: data/images/train/590.jpg
#   inflating: data/images/train/590.xml
#   inflating: data/images/train/591.jpg
#   inflating: data/images/train/591.xml
#   inflating: data/images/train/592.jpg
#   inflating: data/images/train/592.xml
#   inflating: data/images/train/593.jpg
#   inflating: data/images/train/593.xml
#   inflating: data/images/train/595.jpg
#   inflating: data/images/train/595.xml
#   inflating: data/images/train/596.jpg
#   inflating: data/images/train/596.xml
#   inflating: data/images/train/597.jpg
#   inflating: data/images/train/597.xml
#   inflating: data/images/train/599.jpg
#   inflating: data/images/train/599.xml
#   inflating: data/images/train/600.jpg
#   inflating: data/images/train/600.xml
#   inflating: data/images/train/601.jpg
#   inflating: data/images/train/601.xml
#   inflating: data/images/train/602.jpg
#   inflating: data/images/train/602.xml
#   inflating: data/images/train/603.jpg
#   inflating: data/images/train/603.xml
#   inflating: data/images/train/604.jpg
#   inflating: data/images/train/604.xml
#   inflating: data/images/train/605.jpg
#   inflating: data/images/train/605.xml
#   inflating: data/images/train/606.jpg
#   inflating: data/images/train/606.xml
#   inflating: data/images/train/608.jpg
#   inflating: data/images/train/608.xml
#   inflating: data/images/train/610.jpg
#   inflating: data/images/train/610.xml
#   inflating: data/images/train/611.jpg
#   inflating: data/images/train/611.xml
#   inflating: data/images/train/612.jpg
#   inflating: data/images/train/612.xml
#   inflating: data/images/train/613.jpg
#   inflating: data/images/train/613.xml
#   inflating: data/images/train/614.jpg
#   inflating: data/images/train/614.xml
#   inflating: data/images/train/616.jpg
#   inflating: data/images/train/616.xml
#   inflating: data/images/train/617.jpg
#   inflating: data/images/train/617.xml
#   inflating: data/images/train/618.jpg
#   inflating: data/images/train/618.xml
#   inflating: data/images/train/619.jpg
#   inflating: data/images/train/619.xml
#   inflating: data/images/train/620.jpg
#   inflating: data/images/train/620.xml
#   inflating: data/images/train/622.jpg
#   inflating: data/images/train/622.xml
#   inflating: data/images/train/623.jpg
#   inflating: data/images/train/623.xml
#   inflating: data/images/train/624.jpg
#   inflating: data/images/train/624.xml
#   inflating: data/images/train/625.jpg
#   inflating: data/images/train/625.xml
#   inflating: data/images/train/626.jpg
#   inflating: data/images/train/626.xml
#   inflating: data/images/train/627.jpg
#   inflating: data/images/train/627.xml
#   inflating: data/images/train/628.jpg
#   inflating: data/images/train/628.xml
#   inflating: data/images/train/629.jpg
#   inflating: data/images/train/629.xml
#   inflating: data/images/train/630.jpg
#   inflating: data/images/train/630.xml
#   inflating: data/images/train/631.jpg
#   inflating: data/images/train/631.xml
#   inflating: data/images/train/632.jpg
#   inflating: data/images/train/632.xml
#   inflating: data/images/train/633.jpg
#   inflating: data/images/train/633.xml
#   inflating: data/images/train/634.jpg
#   inflating: data/images/train/634.xml
#   inflating: data/images/train/635.jpg
#   inflating: data/images/train/635.xml
#   inflating: data/images/train/636.jpg
#   inflating: data/images/train/636.xml
#   inflating: data/images/train/637.jpg
#   inflating: data/images/train/637.xml
#   inflating: data/images/train/638.jpg
#   inflating: data/images/train/638.xml
#   inflating: data/images/train/639.jpg
#   inflating: data/images/train/639.xml
#   inflating: data/images/train/640.jpg
#   inflating: data/images/train/640.xml
#   inflating: data/images/train/641.jpg
#   inflating: data/images/train/641.xml
#   inflating: data/images/train/643.jpg
#   inflating: data/images/train/643.xml
#   inflating: data/images/train/644.jpg
#   inflating: data/images/train/644.xml
#   inflating: data/images/train/645.jpg
#   inflating: data/images/train/645.xml
#   inflating: data/images/train/646.jpg
#   inflating: data/images/train/646.xml
#   inflating: data/images/train/647.jpg
#   inflating: data/images/train/647.xml
#   inflating: data/images/train/648.jpg
#   inflating: data/images/train/648.xml
#   inflating: data/images/train/649.jpg
#   inflating: data/images/train/649.xml
#   inflating: data/images/train/650.jpg
#   inflating: data/images/train/650.xml
#   inflating: data/images/train/651.jpg
#   inflating: data/images/train/651.xml
#   inflating: data/images/train/652.jpg
#   inflating: data/images/train/652.xml
#   inflating: data/images/train/653.jpg
#   inflating: data/images/train/653.xml
#   inflating: data/images/train/654.jpg
#   inflating: data/images/train/654.xml
#   inflating: data/images/train/655.jpg
#   inflating: data/images/train/655.xml
#   inflating: data/images/train/656.jpg
#   inflating: data/images/train/656.xml
#   inflating: data/images/train/658.jpg
#   inflating: data/images/train/658.xml
#   inflating: data/images/train/659.jpg
#   inflating: data/images/train/659.xml
#   inflating: data/images/train/660.jpg
#   inflating: data/images/train/660.xml
#   inflating: data/images/train/661.jpg
#   inflating: data/images/train/661.xml
#   inflating: data/images/train/662.jpg
#   inflating: data/images/train/662.xml
#   inflating: data/images/train/663.jpg
#   inflating: data/images/train/663.xml
#   inflating: data/images/train/664.jpg
#   inflating: data/images/train/664.xml
#   inflating: data/images/train/665.jpg
#   inflating: data/images/train/665.xml
#   inflating: data/images/train/666.jpg
#   inflating: data/images/train/666.xml
#   inflating: data/images/train/667.jpg
#   inflating: data/images/train/667.xml
#   inflating: data/images/train/669.jpg
#   inflating: data/images/train/669.xml
#   inflating: data/images/train/672.jpg
#   inflating: data/images/train/672.xml
#   inflating: data/images/train/673.jpg
#   inflating: data/images/train/673.xml
#   inflating: data/images/train/674.jpg
#   inflating: data/images/train/674.xml
#   inflating: data/images/train/675.jpg
#   inflating: data/images/train/675.xml
#   inflating: data/images/train/676.jpg
#   inflating: data/images/train/676.xml
#   inflating: data/images/train/677.jpg
#   inflating: data/images/train/677.xml
#   inflating: data/images/train/678.jpg
#   inflating: data/images/train/678.xml
#   inflating: data/images/train/679.jpg
#   inflating: data/images/train/679.xml
#   inflating: data/images/train/680.jpg
#   inflating: data/images/train/680.xml
#   inflating: data/images/train/681.jpg
#   inflating: data/images/train/681.xml
#   inflating: data/images/train/682.jpg
#   inflating: data/images/train/682.xml
#   inflating: data/images/train/683.jpg
#   inflating: data/images/train/683.xml
#   inflating: data/images/train/684.jpg
#   inflating: data/images/train/684.xml
#   inflating: data/images/train/685.jpg
#   inflating: data/images/train/685.xml
#   inflating: data/images/train/686.jpg
#   inflating: data/images/train/686.xml
#   inflating: data/images/train/687.jpg
#   inflating: data/images/train/687.xml
#   inflating: data/images/train/688.jpg
#   inflating: data/images/train/688.xml
# ...
#   inflating: data/images/train/1585.xml
#   inflating: data/images/train/1586.jpg
#   inflating: data/images/train/1586.xml
#   inflating: data/images/train/1587.jpg
#   inflating: data/images/train/1587.xml
#   inflating: data/images/train/1588.jpg
#   inflating: data/images/train/1588.xml
#   inflating: data/images/train/1589.jpg
#   inflating: data/images/train/1589.xml
#   inflating: data/images/train/1590.jpg
#   inflating: data/images/train/1590.xml
#   inflating: data/images/train/1591.jpg
#   inflating: data/images/train/1591.xml
#   inflating: data/images/train/1592.jpg
#   inflating: data/images/train/1592.xml
#   inflating: data/images/train/1593.jpg
#   inflating: data/images/train/1593.xml
#   inflating: data/images/train/1594.jpg
#   inflating: data/images/train/1594.xml
#   inflating: data/images/train/1595.jpg
#   inflating: data/images/train/1595.xml
#   inflating: data/images/train/1596.jpg
#   inflating: data/images/train/1596.xml
#   inflating: data/images/train/1597.jpg
#   inflating: data/images/train/1597.xml
#   inflating: data/images/train/1598.jpg
#   inflating: data/images/train/1598.xml
#   inflating: data/images/train/1599.jpg
#   inflating: data/images/train/1599.xml
#   inflating: data/images/train/1600.jpg
#   inflating: data/images/train/1600.xml
#   inflating: data/images/train/1601.jpg
#   inflating: data/images/train/1601.xml
#   inflating: data/images/train/1602.jpg
#   inflating: data/images/train/1602.xml
#   inflating: data/images/train/1604.jpg
#   inflating: data/images/train/1604.xml
#   inflating: data/images/train/1606.jpg
#   inflating: data/images/train/1606.xml
#   inflating: data/images/train/1607.jpg
#   inflating: data/images/train/1607.xml
#   inflating: data/images/train/1608.jpg
#   inflating: data/images/train/1608.xml
#   inflating: data/images/train/1609.jpg
#   inflating: data/images/train/1609.xml
#   inflating: data/images/train/1610.jpg
#   inflating: data/images/train/1610.xml
#   inflating: data/images/train/1611.jpg
#   inflating: data/images/train/1611.xml
#   inflating: data/images/train/1612.jpg
#   inflating: data/images/train/1612.xml
#   inflating: data/images/train/1613.jpg
#   inflating: data/images/train/1613.xml
#   inflating: data/images/train/1614.jpg
#   inflating: data/images/train/1614.xml
#   inflating: data/images/train/1615.jpg
#   inflating: data/images/train/1615.xml
#   inflating: data/images/train/1616.jpg
#   inflating: data/images/train/1616.xml
#   inflating: data/images/train/1617.jpg
#   inflating: data/images/train/1617.xml
#   inflating: data/images/train/1618.jpg
#   inflating: data/images/train/1618.xml
#   inflating: data/images/train/1619.jpg
#   inflating: data/images/train/1619.xml
#   inflating: data/images/train/1620.jpg
#   inflating: data/images/train/1620.xml
#   inflating: data/images/train/1621.jpg
#   inflating: data/images/train/1621.xml
#   inflating: data/images/train/1622.jpg
#   inflating: data/images/train/1622.xml
#   inflating: data/images/train/1623.jpg
#   inflating: data/images/train/1623.xml
#   inflating: data/images/train/1626.jpg
#   inflating: data/images/train/1626.xml
#   inflating: data/images/train/1627.jpg
#   inflating: data/images/train/1627.xml
#   inflating: data/images/train/1628.jpg
#   inflating: data/images/train/1628.xml
#   inflating: data/images/train/1629.jpg
#   inflating: data/images/train/1629.xml
#   inflating: data/images/train/1631.jpg
#   inflating: data/images/train/1631.xml
#   inflating: data/images/train/1632.jpg
#   inflating: data/images/train/1632.xml
#   inflating: data/images/train/1633.jpg
#   inflating: data/images/train/1633.xml
#   inflating: data/images/train/1635.jpg
#   inflating: data/images/train/1635.xml
#   inflating: data/images/train/1636.jpg
#   inflating: data/images/train/1636.xml
#   inflating: data/images/train/1637.jpg
#   inflating: data/images/train/1637.xml
#   inflating: data/images/train/1638.jpg
#   inflating: data/images/train/1638.xml
#   inflating: data/images/train/1639.jpg
#   inflating: data/images/train/1639.xml
#   inflating: data/images/train/1640.jpg
#   inflating: data/images/train/1640.xml
#   inflating: data/images/train/1641.jpg
#   inflating: data/images/train/1641.xml
#   inflating: data/images/train/1643.jpg
#   inflating: data/images/train/1643.xml
#   inflating: data/images/train/1644.jpg
#   inflating: data/images/train/1644.xml
#   inflating: data/images/train/1645.jpg
#   inflating: data/images/train/1645.xml
#   inflating: data/images/train/1646.jpg
#   inflating: data/images/train/1646.xml
#   inflating: data/images/train/1647.jpg
#   inflating: data/images/train/1647.xml
#   inflating: data/images/train/1648.jpg
#   inflating: data/images/train/1648.xml
#   inflating: data/images/train/1649.jpg
#   inflating: data/images/train/1649.xml
#   inflating: data/images/train/1650.jpg
#   inflating: data/images/train/1650.xml
#   inflating: data/images/train/1651.jpg
#   inflating: data/images/train/1651.xml
#   inflating: data/images/train/1652.jpg
#   inflating: data/images/train/1652.xml
#   inflating: data/images/train/1654.jpg
#   inflating: data/images/train/1654.xml
#   inflating: data/images/train/1655.jpg
#   inflating: data/images/train/1655.xml
#   inflating: data/images/train/1656.jpg
#   inflating: data/images/train/1656.xml
#   inflating: data/images/train/1658.jpg
#   inflating: data/images/train/1658.xml
#   inflating: data/images/train/1659.jpg
#   inflating: data/images/train/1659.xml
#   inflating: data/images/train/1660.jpg
#   inflating: data/images/train/1660.xml
#   inflating: data/images/train/1661.jpg
#   inflating: data/images/train/1661.xml
#   inflating: data/images/train/1662.jpg
#   inflating: data/images/train/1662.xml
#   inflating: data/images/train/1663.jpg
#   inflating: data/images/train/1663.xml
#   inflating: data/images/train/1664.jpg
#   inflating: data/images/train/1664.xml
#   inflating: data/images/train/1665.jpg
#   inflating: data/images/train/1665.xml
#   inflating: data/images/train/1666.jpg
#   inflating: data/images/train/1666.xml
#   inflating: data/images/train/1668.jpg
#   inflating: data/images/train/1668.xml
#   inflating: data/images/train/1669.jpg
#   inflating: data/images/train/1669.xml
#   inflating: data/images/train/1670.jpg
#   inflating: data/images/train/1670.xml
#   inflating: data/images/train/1671.jpg
#   inflating: data/images/train/1671.xml
#   inflating: data/images/train/1673.jpg
#   inflating: data/images/train/1673.xml
#   inflating: data/images/train/1674.jpg
#   inflating: data/images/train/1674.xml
#   inflating: data/images/train/1675.jpg
#   inflating: data/images/train/1675.xml
#   inflating: data/images/train/1676.jpg
#   inflating: data/images/train/1676.xml
#   inflating: data/images/train/1677.jpg
#   inflating: data/images/train/1677.xml
#   inflating: data/images/train/1678.jpg
#   inflating: data/images/train/1678.xml
#   inflating: data/images/train/1679.jpg
#   inflating: data/images/train/1679.xml
#   inflating: data/images/train/1680.jpg
#   inflating: data/images/train/1680.xml
#   inflating: data/images/train/1681.jpg
#   inflating: data/images/train/1681.xml
#   inflating: data/images/train/1682.jpg
#   inflating: data/images/train/1682.xml
#   inflating: data/images/train/1683.jpg
#   inflating: data/images/train/1683.xml
#   inflating: data/images/train/1684.jpg
#   inflating: data/images/train/1684.xml
#   inflating: data/images/train/1685.jpg
#   inflating: data/images/train/1685.xml
#   inflating: data/images/train/1686.jpg
#   inflating: data/images/train/1686.xml
#   inflating: data/images/train/1688.jpg
#   inflating: data/images/train/1688.xml
#   inflating: data/images/train/1689.jpg
#   inflating: data/images/train/1689.xml
#   inflating: data/images/train/1690.jpg
#   inflating: data/images/train/1690.xml
#   inflating: data/images/train/1692.jpg
#   inflating: data/images/train/1692.xml
#   inflating: data/images/train/1693.jpg
#   inflating: data/images/train/1693.xml
#   inflating: data/images/train/1694.jpg
#   inflating: data/images/train/1694.xml
#   inflating: data/images/train/1695.jpg
#   inflating: data/images/train/1695.xml
#   inflating: data/images/train/1697.jpg
#   inflating: data/images/train/1697.xml
#   inflating: data/images/train/1698.jpg
#   inflating: data/images/train/1698.xml
#   inflating: data/images/train/1700.jpg
#   inflating: data/images/train/1700.xml
#   inflating: data/images/train/1701.jpg
#   inflating: data/images/train/1701.xml
#   inflating: data/images/train/1702.jpg
#   inflating: data/images/train/1702.xml
#   inflating: data/images/train/1703.jpg
#   inflating: data/images/train/1703.xml
#   inflating: data/images/train/1704.jpg
#   inflating: data/images/train/1704.xml
#   inflating: data/images/train/1705.jpg
#   inflating: data/images/train/1705.xml
#   inflating: data/images/train/1706.jpg
#   inflating: data/images/train/1706.xml
#   inflating: data/images/train/1707.jpg
#   inflating: data/images/train/1707.xml
#   inflating: data/images/train/1708.jpg
#   inflating: data/images/train/1708.xml
#   inflating: data/images/train/1710.jpg
#   inflating: data/images/train/1710.xml
#   inflating: data/images/train/1711.jpg
#   inflating: data/images/train/1711.xml
#   inflating: data/images/train/1712.jpg
#   inflating: data/images/train/1712.xml
#   inflating: data/images/train/1713.jpg
#   inflating: data/images/train/1713.xml
#   inflating: data/images/train/1714.jpg
#   inflating: data/images/train/1714.xml
#   inflating: data/images/train/1715.jpg
#   inflating: data/images/train/1715.xml
#   inflating: data/images/train/1716.jpg
#   inflating: data/images/train/1716.xml
#   inflating: data/images/train/1717.jpg
#   inflating: data/images/train/1717.xml
#   inflating: data/images/train/1719.jpg
#   inflating: data/images/train/1719.xml
#   inflating: data/images/train/1720.jpg
#   inflating: data/images/train/1720.xml
#   inflating: data/images/train/1722.jpg
#   inflating: data/images/train/1722.xml
#   inflating: data/images/train/1723.jpg
#   inflating: data/images/train/1723.xml
#   inflating: data/images/train/1724.jpg
#   inflating: data/images/train/1724.xml
#   inflating: data/images/train/1726.jpg
#   inflating: data/images/train/1726.xml
#   inflating: data/images/train/1727.jpg
#   inflating: data/images/train/1727.xml
#   inflating: data/images/train/1728.jpg
#   inflating: data/images/train/1728.xml
#   inflating: data/images/train/1729.jpg
#   inflating: data/images/train/1729.xml
#   inflating: data/images/train/1730.jpg
#   inflating: data/images/train/1730.xml
#   inflating: data/images/train/1731.jpg
#   inflating: data/images/train/1731.xml
#   inflating: data/images/train/1732.jpg
#   inflating: data/images/train/1732.xml
#   inflating: data/images/train/1733.jpg
#   inflating: data/images/train/1733.xml
#   inflating: data/images/train/1734.jpg
#   inflating: data/images/train/1734.xml
#   inflating: data/images/train/1735.jpg
#   inflating: data/images/train/1735.xml
#   inflating: data/images/train/1736.jpg
#   inflating: data/images/train/1736.xml
#   inflating: data/images/train/1737.jpg
#   inflating: data/images/train/1737.xml
#   inflating: data/images/train/1738.jpg
#   inflating: data/images/train/1738.xml
#   inflating: data/images/train/1739.jpg
#   inflating: data/images/train/1739.xml
#   inflating: data/images/train/1740.jpg
#   inflating: data/images/train/1740.xml
#   inflating: data/images/train/1741.jpg
#   inflating: data/images/train/1741.xml
#   inflating: data/images/train/1742.jpg
#   inflating: data/images/train/1742.xml
#   inflating: data/images/train/1743.jpg
#   inflating: data/images/train/1743.xml
#   inflating: data/images/train/1744.jpg
#   inflating: data/images/train/1744.xml
#   inflating: data/images/train/1746.jpg
#   inflating: data/images/train/1746.xml
#   inflating: data/images/train/1747.jpg
#   inflating: data/images/train/1747.xml
#   inflating: data/images/train/1748.jpg
#   inflating: data/images/train/1748.xml
#   inflating: data/images/train/1749.jpg
#   inflating: data/images/train/1749.xml
#   inflating: data/images/train/1752.jpg
#   inflating: data/images/train/1752.xml
#   inflating: data/images/train/1753.jpg
#   inflating: data/images/train/1753.xml
#   inflating: data/images/train/1754.jpg
#   inflating: data/images/train/1754.xml
#   inflating: data/images/train/1755.jpg
#   inflating: data/images/train/1755.xml
#   inflating: data/images/train/1756.jpg
#   inflating: data/images/train/1756.xml
#   inflating: data/images/train/1757.jpg
#   inflating: data/images/train/1757.xml
#   inflating: data/images/train/1758.jpg
#   inflating: data/images/train/1758.xml
#   inflating: data/images/train/1759.jpg
#   inflating: data/images/train/1759.xml
#   inflating: data/images/train/1760.jpg
#   inflating: data/images/train/1760.xml
#   inflating: data/images/train/1761.jpg
#   inflating: data/images/train/1761.xml
#   inflating: data/images/train/1762.jpg
#   inflating: data/images/train/1762.xml
#   inflating: data/images/train/1763.jpg
#   inflating: data/images/train/1763.xml
#   inflating: data/images/train/1764.jpg
#   inflating: data/images/train/1764.xml
#   inflating: data/images/train/1765.jpg
#   inflating: data/images/train/1765.xml
#   inflating: data/images/train/1766.jpg
#   inflating: data/images/train/1766.xml
#   inflating: data/images/train/1767.jpg
#   inflating: data/images/train/1767.xml
#   inflating: data/images/train/1768.jpg
#   inflating: data/images/train/1768.xml
#   inflating: data/images/train/1770.jpg
#   inflating: data/images/train/1770.xml
#   inflating: data/images/train/1771.jpg
#   inflating: data/images/train/1771.xml
#   inflating: data/images/train/1772.jpg
#   inflating: data/images/train/1772.xml
#   inflating: data/images/train/1773.jpg
#   inflating: data/images/train/1773.xml
#   inflating: data/images/train/1774.jpg
#   inflating: data/images/train/1774.xml
#   inflating: data/images/train/1775.jpg
#   inflating: data/images/train/1775.xml
#   inflating: data/images/train/1776.jpg
#   inflating: data/images/train/1776.xml
#   inflating: data/images/train/1777.jpg
#   inflating: data/images/train/1777.xml
#   inflating: data/images/train/1778.jpg
#   inflating: data/images/train/1778.xml
#   inflating: data/images/train/1779.jpg
#   inflating: data/images/train/1779.xml
#   inflating: data/images/train/1780.jpg
#   inflating: data/images/train/1780.xml
#   inflating: data/images/train/1782.jpg
#   inflating: data/images/train/1782.xml
#   inflating: data/images/train/1783.jpg
#   inflating: data/images/train/1783.xml
#   inflating: data/images/train/1784.jpg
#   inflating: data/images/train/1784.xml
#   inflating: data/images/train/1785.jpg
#   inflating: data/images/train/1785.xml
#   inflating: data/images/train/1786.jpg
#   inflating: data/images/train/1786.xml
#   inflating: data/images/train/1787.jpg
#   inflating: data/images/train/1787.xml
#   inflating: data/images/train/1788.jpg
#   inflating: data/images/train/1788.xml
#   inflating: data/images/train/1789.jpg
#   inflating: data/images/train/1789.xml
#   inflating: data/images/train/1790.jpg
#   inflating: data/images/train/1790.xml
#   inflating: data/images/train/1791.jpg
#   inflating: data/images/train/1791.xml
#   inflating: data/images/train/1792.jpg
#   inflating: data/images/train/1792.xml
#   inflating: data/images/train/1793.jpg
#   inflating: data/images/train/1793.xml
#   inflating: data/images/train/1794.jpg
#   inflating: data/images/train/1794.xml
#   inflating: data/images/train/1795.jpg
#   inflating: data/images/train/1795.xml
#   inflating: data/images/train/1796.jpg
#   inflating: data/images/train/1796.xml
#   inflating: data/images/train/1797.jpg
#   inflating: data/images/train/1797.xml
#   inflating: data/images/train/1798.jpg
#   inflating: data/images/train/1798.xml
#   inflating: data/images/train/1799.jpg
#   inflating: data/images/train/1799.xml

# %% [markdown]
# ## Prepare `tfrecord` files
#
# Use the following scripts to generate the `tfrecord` files.
# ```bash
# # Convert train folder annotation xml files to a single csv file,
# # generate the `label_map.pbtxt` file to `data/` directory as well.
# python xml_to_csv.py -i data/images/train -o data/annotations/train_labels.csv -l data/annotations
#
# # Convert test folder annotation xml files to a single csv.
# python xml_to_csv.py -i data/images/test -o data/annotations/test_labels.csv
#
# # Generate `train.record`
# python generate_tfrecord.py --csv_input=data/annotations/train_labels.csv --output_path=data/annotations/train.record --img_path=data/images/train --label_map data/annotations/label_map.pbtxt
#
# # Generate `test.record`
# python generate_tfrecord.py --csv_input=data/annotations/test_labels.csv --output_path=data/annotations/test.record --img_path=data/images/test --label_map data/annotations/label_map.pbtxt
# ```

# %%
# %cd {repo_dir_path}

# Convert train folder annotation xml files to a single csv file,
# generate the `label_map.pbtxt` file to `data/` directory as well.
# !python xml_to_csv.py -i data/images/train -o data/annotations/train_labels.csv -l data/annotations

# Convert test folder annotation xml files to a single csv.
# !python xml_to_csv.py -i data/images/test -o data/annotations/test_labels.csv

# Generate `train.record`
# !python generate_tfrecord.py --csv_input=data/annotations/train_labels.csv --output_path=data/annotations/train.record --img_path=data/images/train --label_map data/annotations/label_map.pbtxt

# Generate `test.record`
# !python generate_tfrecord.py --csv_input=data/annotations/test_labels.csv --output_path=data/annotations/test.record --img_path=data/images/test --label_map data/annotations/label_map.pbtxt
# Out:
# /content/object_detection_demo
# Successfully converted xml to csv.
# Generate `data/annotations/label_map.pbtxt`
# Successfully converted xml to csv.
# WARNING:tensorflow:From generate_tfrecord.py:134: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From generate_tfrecord.py:107: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# W0826 20:37:55.607736 139906001192832 module_wrapper.py:139] From generate_tfrecord.py:107: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# WARNING:tensorflow:From generate_tfrecord.py:53: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W0826 20:37:56.075273 139906001192832 module_wrapper.py:139] From generate_tfrecord.py:53: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# Successfully created the TFRecords: /content/object_detection_demo/data/annotations/train.record
# WARNING:tensorflow:From generate_tfrecord.py:134: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From generate_tfrecord.py:107: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# W0826 20:38:00.254795 140646676694912 module_wrapper.py:139] From generate_tfrecord.py:107: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# WARNING:tensorflow:From generate_tfrecord.py:53: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W0826 20:38:00.268962 140646676694912 module_wrapper.py:139] From generate_tfrecord.py:53: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# Successfully created the TFRecords: /content/object_detection_demo/data/annotations/test.record

# %%
test_record_fname = '/content/object_detection_demo/data/annotations/test.record'
train_record_fname = '/content/object_detection_demo/data/annotations/train.record'
label_map_pbtxt_fname = '/content/object_detection_demo/data/annotations/label_map.pbtxt'

# %% [markdown]
# ## Download base model

# %%
# %cd /content/models/research

import os
import shutil
import glob
import urllib.request
import tarfile
MODEL_FILE = MODEL + '.tar.gz'
DOWNLOAD_BASE = 'http://download.tensorflow.org/models/object_detection/'
DEST_DIR = '/content/models/research/pretrained_model'

if not (os.path.exists(MODEL_FILE)):
    urllib.request.urlretrieve(DOWNLOAD_BASE + MODEL_FILE, MODEL_FILE)

tar = tarfile.open(MODEL_FILE)
tar.extractall()
tar.close()

os.remove(MODEL_FILE)
if (os.path.exists(DEST_DIR)):
    shutil.rmtree(DEST_DIR)
os.rename(MODEL, DEST_DIR)
# Out:
# /content/models/research

# %%
# !echo {DEST_DIR}
# !ls -alh {DEST_DIR}
# Out:
# /content/models/research/pretrained_model
# total 476M
# drwxr-xr-x  3 345018 5000 4.0K Feb  1  2018 .
# drwxr-xr-x 23 root   root 4.0K Aug 26 20:38 ..
# -rw-r--r--  1 345018 5000   77 Feb  1  2018 checkpoint
# -rw-r--r--  1 345018 5000 208M Feb  1  2018 frozen_inference_graph.pb
# -rw-r--r--  1 345018 5000 262M Feb  1  2018 model.ckpt.data-00000-of-00001
# -rw-r--r--  1 345018 5000  26K Feb  1  2018 model.ckpt.index
# -rw-r--r--  1 345018 5000 6.4M Feb  1  2018 model.ckpt.meta
# -rw-r--r--  1 345018 5000 3.1K Feb  1  2018 pipeline.config
# drwxr-xr-x  3 345018 5000 4.0K Feb  1  2018 saved_model

# %%
fine_tune_checkpoint = os.path.join(DEST_DIR, "model.ckpt")
fine_tune_checkpoint
# Out:
# '/content/models/research/pretrained_model/model.ckpt'

# %% [markdown]
# ## Configuring a Training Pipeline

# %%
import os
pipeline_fname = os.path.join('/content/models/research/object_detection/samples/configs/', pipeline_file)

assert os.path.isfile(pipeline_fname), '`{}` not exist'.format(pipeline_fname)

# %%
def get_num_classes(pbtxt_fname):
    from object_detection.utils import label_map_util
    label_map = label_map_util.load_labelmap(pbtxt_fname)
    categories = label_map_util.convert_label_map_to_categories(
        label_map, max_num_classes=90, use_display_name=True)
    category_index = label_map_util.create_category_index(categories)
    return len(category_index.keys())

# %%
import re

num_classes = get_num_classes(label_map_pbtxt_fname)
with open(pipeline_fname) as f:
    s = f.read()
with open(pipeline_fname, 'w') as f:
    
    # fine_tune_checkpoint
    s = re.sub('fine_tune_checkpoint: ".*?"',
               'fine_tune_checkpoint: "{}"'.format(fine_tune_checkpoint), s)
    
    # tfrecord files train and test.
    s = re.sub(
        '(input_path: ".*?)(train.record)(.*?")', 'input_path: "{}"'.format(train_record_fname), s)
    s = re.sub(
        '(input_path: ".*?)(val.record)(.*?")', 'input_path: "{}"'.format(test_record_fname), s)

    # label_map_path
    s = re.sub(
        'label_map_path: ".*?"', 'label_map_path: "{}"'.format(label_map_pbtxt_fname), s)

    # Set training batch_size.
    s = re.sub('batch_size: [0-9]+',
               'batch_size: {}'.format(batch_size), s)

    # Set training steps, num_steps
    s = re.sub('num_steps: [0-9]+',
               'num_steps: {}'.format(num_steps), s)
    
    # Set number of classes num_classes.
    s = re.sub('num_classes: [0-9]+',
               'num_classes: {}'.format(num_classes), s)
    f.write(s)

# %%
# !cat {pipeline_fname}
# Out:
# # R-FCN with Resnet-101 (v1),  configured for Oxford-IIIT Pets Dataset.
# # Users should configure the fine_tune_checkpoint field in the train config as
# # well as the label_map_path and input_path fields in the train_input_reader and
# # eval_input_reader. Search for "PATH_TO_BE_CONFIGURED" to find the fields that
# # should be configured.
#
# model {
#   faster_rcnn {
#     num_classes: 5
#     image_resizer {
#       keep_aspect_ratio_resizer {
#         min_dimension: 600
#         max_dimension: 1024
#       }
#     }
#     feature_extractor {
#       type: 'faster_rcnn_resnet101'
#       first_stage_features_stride: 16
#     }
#     first_stage_anchor_generator {
#       grid_anchor_generator {
#         scales: [0.25, 0.5, 1.0, 2.0]
#         aspect_ratios: [0.5, 1.0, 2.0]
#         height_stride: 16
#         width_stride: 16
#       }
#     }
#     first_stage_box_predictor_conv_hyperparams {
#       op: CONV
#       regularizer {
#         l2_regularizer {
#           weight: 0.0
#         }
#       }
#       initializer {
#         truncated_normal_initializer {
#           stddev: 0.01
#         }
#       }
#     }
#     first_stage_nms_score_threshold: 0.0
#     first_stage_nms_iou_threshold: 0.7
#     first_stage_max_proposals: 300
#     first_stage_localization_loss_weight: 2.0
#     first_stage_objectness_loss_weight: 1.0
#     second_stage_box_predictor {
#       rfcn_box_predictor {
#         conv_hyperparams {
#           op: CONV
#           regularizer {
#             l2_regularizer {
#               weight: 0.0
#             }
#           }
#           initializer {
#             truncated_normal_initializer {
#               stddev: 0.01
#             }
#           }
#         }
#         crop_height: 18
#         crop_width: 18
#         num_spatial_bins_height: 3
#         num_spatial_bins_width: 3
#       }
#     }
#     second_stage_post_processing {
#       batch_non_max_suppression {
#         score_threshold: 0.0
#         iou_threshold: 0.6
#         max_detections_per_class: 100
#         max_total_detections: 300
#       }
#       score_converter: SOFTMAX
#     }
#     second_stage_localization_loss_weight: 2.0
#     second_stage_classification_loss_weight: 1.0
#   }
# }
#
# train_config: {
#   batch_size: 8
#   optimizer {
#     momentum_optimizer: {
#       learning_rate: {
#         manual_step_learning_rate {
#           initial_learning_rate: 0.0003
#           schedule {
#             step: 900000
#             learning_rate: .00003
#           }
#           schedule {
#             step: 1200000
#             learning_rate: .000003
#           }
#         }
#       }
#       momentum_optimizer_value: 0.9
#     }
#     use_moving_average: false
#   }
#   gradient_clipping_by_norm: 10.0
#   fine_tune_checkpoint: "/content/models/research/pretrained_model/model.ckpt"
#   from_detection_checkpoint: true
#   load_all_detection_checkpoint_vars: true
#   # Note: The below line limits the training process to 200K steps, which we
#   # empirically found to be sufficient enough to train the pets dataset. This
#   # effectively bypasses the learning rate schedule (the learning rate will
#   # never decay). Remove the below line to train indefinitely.
#   num_steps: 10000
#   data_augmentation_options {
#     random_horizontal_flip {
#     }
#   }
# }
#
# train_input_reader: {
#   tf_record_input_reader {
#     input_path: "/content/object_detection_demo/data/annotations/train.record"
#   }
#   label_map_path: "/content/object_detection_demo/data/annotations/label_map.pbtxt"
# }
#
# eval_config: {
#   metrics_set: "coco_detection_metrics"
#   num_examples: 1101
# }
#
# eval_input_reader: {
#   tf_record_input_reader {
#     input_path: "/content/object_detection_demo/data/annotations/test.record"
#   }
#   label_map_path: "/content/object_detection_demo/data/annotations/label_map.pbtxt"
#   shuffle: false
#   num_readers: 1
# }

# %%
model_dir = 'training/'
# Optionally remove content in output model directory to fresh start.
# !rm -rf {model_dir}
os.makedirs(model_dir, exist_ok=True)

# %% [markdown]
# ## Run Tensorboard(Optional)

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip -o ngrok-stable-linux-amd64.zip
# Out:
# --2020-08-26 20:38:27--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 54.88.63.64, 34.233.195.104, 107.23.162.152, ...
# Connecting to bin.equinox.io (bin.equinox.io)|54.88.63.64|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13773305 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip.1’
#
# ngrok-stable-linux- 100%[===================>]  13.13M  15.5MB/s    in 0.8s
#
# 2020-08-26 20:38:29 (15.5 MB/s) - ‘ngrok-stable-linux-amd64.zip.1’ saved [13773305/13773305]
#
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok

# %%
LOG_DIR = model_dir
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR)
)

# %%
get_ipython().system_raw('./ngrok http 6006 &')

# %% [markdown]
# ### Get Tensorboard link

# %%
! curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# http://a99dd681c447.ngrok.io

# %% [markdown]
# ## Train the model

# %%
# !python /content/models/research/object_detection/model_main.py \
    --pipeline_config_path={pipeline_fname} \
    --model_dir={model_dir} \
    --alsologtostderr \
    --num_train_steps={num_steps} \
    --num_eval_steps={num_eval_steps}
# Out:
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W0826 20:38:41.700456 140674866423680 model_lib.py:771] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting train_steps: 10000
# I0826 20:38:41.700692 140674866423680 config_util.py:552] Maybe overwriting train_steps: 10000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0826 20:38:41.700796 140674866423680 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: 1
# I0826 20:38:41.700879 140674866423680 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: 1
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I0826 20:38:41.700967 140674866423680 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# W0826 20:38:41.701071 140674866423680 model_lib.py:787] Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# INFO:tensorflow:create_estimator_and_inputs: use_tpu False, export_to_tpu None
# I0826 20:38:41.701165 140674866423680 model_lib.py:822] create_estimator_and_inputs: use_tpu False, export_to_tpu None
# INFO:tensorflow:Using config: {'_model_dir': 'training/', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7ff0f972efd0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# I0826 20:38:41.701683 140674866423680 estimator.py:212] Using config: {'_model_dir': 'training/', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7ff0f972efd0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:Estimator's model_fn (<function create_model_fn.<locals>.model_fn at 0x7ff0f97447b8>) includes params argument, but params are not passed to Estimator.
# W0826 20:38:41.702407 140674866423680 model_fn.py:630] Estimator's model_fn (<function create_model_fn.<locals>.model_fn at 0x7ff0f97447b8>) includes params argument, but params are not passed to Estimator.
# INFO:tensorflow:Not using Distribute Coordinator.
# I0826 20:38:41.703115 140674866423680 estimator_training.py:186] Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# I0826 20:38:41.703319 140674866423680 training.py:612] Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# I0826 20:38:41.703622 140674866423680 training.py:700] Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# W0826 20:38:41.716135 140674866423680 deprecation.py:323] From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0826 20:38:41.748659 140674866423680 dataset_builder.py:83] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /content/models/research/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.experimental.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_determinstic`.
# W0826 20:38:41.754194 140674866423680 deprecation.py:323] From /content/models/research/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.experimental.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_determinstic`.
# WARNING:tensorflow:From /content/models/research/object_detection/builders/dataset_builder.py:175: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0826 20:38:41.775400 140674866423680 deprecation.py:323] From /content/models/research/object_detection/builders/dataset_builder.py:175: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:Entity <bound method TfExampleDecoder.decode of <object_detection.data_decoders.tf_example_decoder.TfExampleDecoder object at 0x7ff0f924ee80>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# W0826 20:38:41.808969 140674866423680 ag_logging.py:146] Entity <bound method TfExampleDecoder.decode of <object_detection.data_decoders.tf_example_decoder.TfExampleDecoder object at 0x7ff0f924ee80>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <function train_input.<locals>.transform_and_pad_input_data_fn at 0x7ff0f9744ae8> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# W0826 20:38:42.003854 140674866423680 ag_logging.py:146] Entity <function train_input.<locals>.transform_and_pad_input_data_fn at 0x7ff0f9744ae8> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:From /content/models/research/object_detection/inputs.py:80: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0826 20:38:42.010140 140674866423680 deprecation.py:323] From /content/models/research/object_detection/inputs.py:80: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /content/models/research/object_detection/utils/ops.py:493: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0826 20:38:42.017737 140674866423680 deprecation.py:323] From /content/models/research/object_detection/utils/ops.py:493: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/models/research/object_detection/inputs.py:261: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0826 20:38:42.157654 140674866423680 deprecation.py:323] From /content/models/research/object_detection/inputs.py:261: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Calling model_fn.
# I0826 20:38:42.599625 140674866423680 estimator.py:1148] Calling model_fn.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0826 20:38:42.841452 140674866423680 regularizers.py:99] Scale of 0 disables regularizer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tf_slim/layers/layers.py:1089: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W0826 20:38:42.845927 140674866423680 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tf_slim/layers/layers.py:1089: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0826 20:38:45.674697 140674866423680 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0826 20:38:45.812069 140674866423680 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0826 20:38:45.812441 140674866423680 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0826 20:38:50.202367 140674866423680 regularizers.py:99] Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# I0826 20:38:50.470093 140674866423680 regularizers.py:99] Scale of 0 disables regularizer.
# WARNING:tensorflow:From /content/models/research/object_detection/utils/ops.py:767: calling crop_and_resize_v1 (from tensorflow.python.ops.image_ops_impl) with box_ind is deprecated and will be removed in a future version.
# Instructions for updating:
# box_ind is deprecated, use box_indices instead
# W0826 20:38:50.582173 140674866423680 deprecation.py:506] From /content/models/research/object_detection/utils/ops.py:767: calling crop_and_resize_v1 (from tensorflow.python.ops.image_ops_impl) with box_ind is deprecated and will be removed in a future version.
# Instructions for updating:
# box_ind is deprecated, use box_indices instead
# WARNING:tensorflow:From /content/models/research/object_detection/core/losses.py:380: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# W0826 20:38:54.509893 140674866423680 deprecation.py:323] From /content/models/research/object_detection/core/losses.py:380: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "

# %%
# !ls {model_dir}
# Out:
# checkpoint
# eval_0
# events.out.tfevents.1598355066.b80b181e8210
# export
# graph.pbtxt
# model.ckpt-72022.data-00000-of-00001
# model.ckpt-72022.index
# model.ckpt-72022.meta
# model.ckpt-74282.data-00000-of-00001
# model.ckpt-74282.index
# model.ckpt-74282.meta
# model.ckpt-76501.data-00000-of-00001
# model.ckpt-76501.index
# model.ckpt-76501.meta
# model.ckpt-78723.data-00000-of-00001
# model.ckpt-78723.index
# model.ckpt-78723.meta
# model.ckpt-80000.data-00000-of-00001
# model.ckpt-80000.index
# model.ckpt-80000.meta

# %%
# Legacy way of training(also works).
# !python /content/models/research/object_detection/legacy/train.py --logtostderr --train_dir={model_dir} --pipeline_config_path={pipeline_fname}

# %% [markdown]
# ## Exporting a Trained Inference Graph
# Once your training job is complete, you need to extract the newly trained inference graph, which will be later used to perform the object detection. This can be done as follows:

# %%
import re
import numpy as np

output_directory = './fine_tuned_model'

lst = os.listdir(model_dir)
lst = [l for l in lst if 'model.ckpt-' in l and '.meta' in l]
steps=np.array([int(re.findall('\d+', l)[0]) for l in lst])
last_model = lst[steps.argmax()].replace('.meta', '')

last_model_path = os.path.join(model_dir, last_model)
print(last_model_path)
# !python /content/models/research/object_detection/export_inference_graph.py \
    --input_type=image_tensor \
    --pipeline_config_path={pipeline_fname} \
    --output_directory={output_directory} \
    --trained_checkpoint_prefix={last_model_path}
# Out:
# training/model.ckpt-80000
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tf_slim/layers/layers.py:1089: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W0825 18:04:08.466172 139811698919296 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tf_slim/layers/layers.py:1089: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0825 18:04:10.666214 139811698919296 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0825 18:04:10.706587 139811698919296 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0825 18:04:10.853497 139811698919296 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0825 18:04:10.892475 139811698919296 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0825 18:04:10.934598 139811698919296 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0825 18:04:10.975007 139811698919296 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# WARNING:tensorflow:From /content/models/research/object_detection/core/post_processing.py:595: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0825 18:04:11.254684 139811698919296 deprecation.py:323] From /content/models/research/object_detection/core/post_processing.py:595: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/models/research/object_detection/exporter.py:474: get_or_create_global_step (from tf_slim.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.get_or_create_global_step
# W0825 18:04:11.746780 139811698919296 deprecation.py:323] From /content/models/research/object_detection/exporter.py:474: get_or_create_global_step (from tf_slim.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.get_or_create_global_step
# WARNING:tensorflow:From /content/models/research/object_detection/exporter.py:653: print_model_analysis (from tensorflow.contrib.tfprof.model_analyzer) is deprecated and will be removed after 2018-01-01.
# Instructions for updating:
# Use `tf.profiler.profile(graph, run_meta, op_log, cmd, options)`. Build `options` with `tf.profiler.ProfileOptionBuilder`. See README.md for details
# W0825 18:04:11.750439 139811698919296 deprecation.py:323] From /content/models/research/object_detection/exporter.py:653: print_model_analysis (from tensorflow.contrib.tfprof.model_analyzer) is deprecated and will be removed after 2018-01-01.
# Instructions for updating:
# Use `tf.profiler.profile(graph, run_meta, op_log, cmd, options)`. Build `options` with `tf.profiler.ProfileOptionBuilder`. See README.md for details
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/profiler/internal/flops_registry.py:142: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# W0825 18:04:11.750991 139811698919296 deprecation.py:323] From /tensorflow-1.15.2/python3.6/tensorflow_core/python/profiler/internal/flops_registry.py:142: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# 141 ops no flops stats due to incomplete shapes.
# Parsing Inputs...
# Incomplete shape.
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              0
# -min_occurrence             0
# -step                       -1
# -order_by                   name
# -account_type_regexes       _trainable_variables
# -start_name_regexes         .*
# -trim_name_regexes          .*BatchNorm.*
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     params
# -output                     stdout:
#
# ==================Model Analysis Report======================
# Incomplete shape.
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# param: Number of parameters (in the Variable).
#
# Profile:
# node name | # parameters
# _TFProfRoot (--/4.64m params)
#   BoxPredictor_0 (--/17.31k params)
#     BoxPredictor_0/BoxEncodingPredictor (--/6.92k params)
#       BoxPredictor_0/BoxEncodingPredictor/biases (12, 12/12 params)
#       BoxPredictor_0/BoxEncodingPredictor/weights (1x1x576x12, 6.91k/6.91k params)
#     BoxPredictor_0/ClassPredictor (--/10.39k params)
#       BoxPredictor_0/ClassPredictor/biases (18, 18/18 params)
#       BoxPredictor_0/ClassPredictor/weights (1x1x576x18, 10.37k/10.37k params)
#   BoxPredictor_1 (--/76.86k params)
#     BoxPredictor_1/BoxEncodingPredictor (--/30.74k params)
#       BoxPredictor_1/BoxEncodingPredictor/biases (24, 24/24 params)
#       BoxPredictor_1/BoxEncodingPredictor/weights (1x1x1280x24, 30.72k/30.72k params)
#     BoxPredictor_1/ClassPredictor (--/46.12k params)
#       BoxPredictor_1/ClassPredictor/biases (36, 36/36 params)
#       BoxPredictor_1/ClassPredictor/weights (1x1x1280x36, 46.08k/46.08k params)
#   BoxPredictor_2 (--/30.78k params)
#     BoxPredictor_2/BoxEncodingPredictor (--/12.31k params)
#       BoxPredictor_2/BoxEncodingPredictor/biases (24, 24/24 params)
#       BoxPredictor_2/BoxEncodingPredictor/weights (1x1x512x24, 12.29k/12.29k params)
#     BoxPredictor_2/ClassPredictor (--/18.47k params)
#       BoxPredictor_2/ClassPredictor/biases (36, 36/36 params)
#       BoxPredictor_2/ClassPredictor/weights (1x1x512x36, 18.43k/18.43k params)
#   BoxPredictor_3 (--/15.42k params)
#     BoxPredictor_3/BoxEncodingPredictor (--/6.17k params)
#       BoxPredictor_3/BoxEncodingPredictor/biases (24, 24/24 params)
#       BoxPredictor_3/BoxEncodingPredictor/weights (1x1x256x24, 6.14k/6.14k params)
#     BoxPredictor_3/ClassPredictor (--/9.25k params)
#       BoxPredictor_3/ClassPredictor/biases (36, 36/36 params)
#       BoxPredictor_3/ClassPredictor/weights (1x1x256x36, 9.22k/9.22k params)
#   BoxPredictor_4 (--/15.42k params)
#     BoxPredictor_4/BoxEncodingPredictor (--/6.17k params)
#       BoxPredictor_4/BoxEncodingPredictor/biases (24, 24/24 params)
#       BoxPredictor_4/BoxEncodingPredictor/weights (1x1x256x24, 6.14k/6.14k params)
#     BoxPredictor_4/ClassPredictor (--/9.25k params)
#       BoxPredictor_4/ClassPredictor/biases (36, 36/36 params)
#       BoxPredictor_4/ClassPredictor/weights (1x1x256x36, 9.22k/9.22k params)
#   BoxPredictor_5 (--/7.74k params)
#     BoxPredictor_5/BoxEncodingPredictor (--/3.10k params)
#       BoxPredictor_5/BoxEncodingPredictor/biases (24, 24/24 params)
#       BoxPredictor_5/BoxEncodingPredictor/weights (1x1x128x24, 3.07k/3.07k params)
#     BoxPredictor_5/ClassPredictor (--/4.64k params)
#       BoxPredictor_5/ClassPredictor/biases (36, 36/36 params)
#       BoxPredictor_5/ClassPredictor/weights (1x1x128x36, 4.61k/4.61k params)
#   FeatureExtractor (--/4.48m params)
#     FeatureExtractor/MobilenetV2 (--/4.48m params)
#       FeatureExtractor/MobilenetV2/Conv (--/864 params)
#         FeatureExtractor/MobilenetV2/Conv/BatchNorm (--/0 params)
#         FeatureExtractor/MobilenetV2/Conv/weights (3x3x3x32, 864/864 params)
#       FeatureExtractor/MobilenetV2/Conv_1 (--/409.60k params)
#         FeatureExtractor/MobilenetV2/Conv_1/BatchNorm (--/0 params)
#         FeatureExtractor/MobilenetV2/Conv_1/weights (1x1x320x1280, 409.60k/409.60k params)
#       FeatureExtractor/MobilenetV2/expanded_conv (--/800 params)
#         FeatureExtractor/MobilenetV2/expanded_conv/depthwise (--/288 params)
#           FeatureExtractor/MobilenetV2/expanded_conv/depthwise/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv/depthwise/depthwise_weights (3x3x32x1, 288/288 params)
#         FeatureExtractor/MobilenetV2/expanded_conv/project (--/512 params)
#           FeatureExtractor/MobilenetV2/expanded_conv/project/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv/project/weights (1x1x32x16, 512/512 params)
#       FeatureExtractor/MobilenetV2/expanded_conv_1 (--/4.70k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_1/depthwise (--/864 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_1/depthwise/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_1/depthwise/depthwise_weights (3x3x96x1, 864/864 params)
#         FeatureExtractor/MobilenetV2/expanded_conv_1/expand (--/1.54k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_1/expand/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_1/expand/weights (1x1x16x96, 1.54k/1.54k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_1/project (--/2.30k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_1/project/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_1/project/weights (1x1x96x24, 2.30k/2.30k params)
#       FeatureExtractor/MobilenetV2/expanded_conv_10 (--/64.90k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_10/depthwise (--/3.46k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_10/depthwise/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_10/depthwise/depthwise_weights (3x3x384x1, 3.46k/3.46k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_10/expand (--/24.58k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_10/expand/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_10/expand/weights (1x1x64x384, 24.58k/24.58k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_10/project (--/36.86k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_10/project/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_10/project/weights (1x1x384x96, 36.86k/36.86k params)
#       FeatureExtractor/MobilenetV2/expanded_conv_11 (--/115.78k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_11/depthwise (--/5.18k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_11/depthwise/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_11/depthwise/depthwise_weights (3x3x576x1, 5.18k/5.18k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_11/expand (--/55.30k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_11/expand/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_11/expand/weights (1x1x96x576, 55.30k/55.30k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_11/project (--/55.30k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_11/project/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_11/project/weights (1x1x576x96, 55.30k/55.30k params)
#       FeatureExtractor/MobilenetV2/expanded_conv_12 (--/115.78k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_12/depthwise (--/5.18k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_12/depthwise/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_12/depthwise/depthwise_weights (3x3x576x1, 5.18k/5.18k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_12/expand (--/55.30k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_12/expand/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_12/expand/weights (1x1x96x576, 55.30k/55.30k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_12/project (--/55.30k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_12/project/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_12/project/weights (1x1x576x96, 55.30k/55.30k params)
#       FeatureExtractor/MobilenetV2/expanded_conv_13 (--/152.64k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_13/depthwise (--/5.18k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_13/depthwise/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_13/depthwise/depthwise_weights (3x3x576x1, 5.18k/5.18k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_13/expand (--/55.30k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_13/expand/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_13/expand/weights (1x1x96x576, 55.30k/55.30k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_13/project (--/92.16k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_13/project/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_13/project/weights (1x1x576x160, 92.16k/92.16k params)
#       FeatureExtractor/MobilenetV2/expanded_conv_14 (--/315.84k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_14/depthwise (--/8.64k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_14/depthwise/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_14/depthwise/depthwise_weights (3x3x960x1, 8.64k/8.64k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_14/expand (--/153.60k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_14/expand/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_14/expand/weights (1x1x160x960, 153.60k/153.60k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_14/project (--/153.60k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_14/project/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_14/project/weights (1x1x960x160, 153.60k/153.60k params)
#       FeatureExtractor/MobilenetV2/expanded_conv_15 (--/315.84k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_15/depthwise (--/8.64k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_15/depthwise/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_15/depthwise/depthwise_weights (3x3x960x1, 8.64k/8.64k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_15/expand (--/153.60k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_15/expand/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_15/expand/weights (1x1x160x960, 153.60k/153.60k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_15/project (--/153.60k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_15/project/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_15/project/weights (1x1x960x160, 153.60k/153.60k params)
#       FeatureExtractor/MobilenetV2/expanded_conv_16 (--/469.44k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise (--/8.64k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise/depthwise_weights (3x3x960x1, 8.64k/8.64k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_16/expand (--/153.60k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_16/expand/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_16/expand/weights (1x1x160x960, 153.60k/153.60k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_16/project (--/307.20k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_16/project/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_16/project/weights (1x1x960x320, 307.20k/307.20k params)
#       FeatureExtractor/MobilenetV2/expanded_conv_2 (--/8.21k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_2/depthwise (--/1.30k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_2/depthwise/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_2/depthwise/depthwise_weights (3x3x144x1, 1.30k/1.30k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_2/expand (--/3.46k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_2/expand/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_2/expand/weights (1x1x24x144, 3.46k/3.46k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_2/project (--/3.46k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_2/project/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_2/project/weights (1x1x144x24, 3.46k/3.46k params)
#       FeatureExtractor/MobilenetV2/expanded_conv_3 (--/9.36k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_3/depthwise (--/1.30k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_3/depthwise/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_3/depthwise/depthwise_weights (3x3x144x1, 1.30k/1.30k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_3/expand (--/3.46k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_3/expand/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_3/expand/weights (1x1x24x144, 3.46k/3.46k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_3/project (--/4.61k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_3/project/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_3/project/weights (1x1x144x32, 4.61k/4.61k params)
#       FeatureExtractor/MobilenetV2/expanded_conv_4 (--/14.02k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_4/depthwise (--/1.73k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_4/depthwise/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_4/depthwise/depthwise_weights (3x3x192x1, 1.73k/1.73k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_4/expand (--/6.14k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_4/expand/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_4/expand/weights (1x1x32x192, 6.14k/6.14k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_4/project (--/6.14k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_4/project/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_4/project/weights (1x1x192x32, 6.14k/6.14k params)
#       FeatureExtractor/MobilenetV2/expanded_conv_5 (--/14.02k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_5/depthwise (--/1.73k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_5/depthwise/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_5/depthwise/depthwise_weights (3x3x192x1, 1.73k/1.73k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_5/expand (--/6.14k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_5/expand/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_5/expand/weights (1x1x32x192, 6.14k/6.14k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_5/project (--/6.14k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_5/project/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_5/project/weights (1x1x192x32, 6.14k/6.14k params)
#       FeatureExtractor/MobilenetV2/expanded_conv_6 (--/20.16k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_6/depthwise (--/1.73k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_6/depthwise/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_6/depthwise/depthwise_weights (3x3x192x1, 1.73k/1.73k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_6/expand (--/6.14k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_6/expand/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_6/expand/weights (1x1x32x192, 6.14k/6.14k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_6/project (--/12.29k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_6/project/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_6/project/weights (1x1x192x64, 12.29k/12.29k params)
#       FeatureExtractor/MobilenetV2/expanded_conv_7 (--/52.61k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_7/depthwise (--/3.46k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_7/depthwise/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_7/depthwise/depthwise_weights (3x3x384x1, 3.46k/3.46k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_7/expand (--/24.58k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_7/expand/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_7/expand/weights (1x1x64x384, 24.58k/24.58k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_7/project (--/24.58k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_7/project/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_7/project/weights (1x1x384x64, 24.58k/24.58k params)
#       FeatureExtractor/MobilenetV2/expanded_conv_8 (--/52.61k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_8/depthwise (--/3.46k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_8/depthwise/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_8/depthwise/depthwise_weights (3x3x384x1, 3.46k/3.46k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_8/expand (--/24.58k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_8/expand/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_8/expand/weights (1x1x64x384, 24.58k/24.58k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_8/project (--/24.58k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_8/project/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_8/project/weights (1x1x384x64, 24.58k/24.58k params)
#       FeatureExtractor/MobilenetV2/expanded_conv_9 (--/52.61k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_9/depthwise (--/3.46k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_9/depthwise/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_9/depthwise/depthwise_weights (3x3x384x1, 3.46k/3.46k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_9/expand (--/24.58k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_9/expand/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_9/expand/weights (1x1x64x384, 24.58k/24.58k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_9/project (--/24.58k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_9/project/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_9/project/weights (1x1x384x64, 24.58k/24.58k params)
#       FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256 (--/327.68k params)
#         FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256/BatchNorm (--/0 params)
#         FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256/weights (1x1x1280x256, 327.68k/327.68k params)
#       FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128 (--/65.54k params)
#         FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128/BatchNorm (--/0 params)
#         FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128/weights (1x1x512x128, 65.54k/65.54k params)
#       FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128 (--/32.77k params)
#         FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128/BatchNorm (--/0 params)
#         FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128/weights (1x1x256x128, 32.77k/32.77k params)
#       FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64 (--/16.38k params)
#         FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64/BatchNorm (--/0 params)
#         FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64/weights (1x1x256x64, 16.38k/16.38k params)
#       FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512 (--/1.18m params)
#         FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512/BatchNorm (--/0 params)
#         FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512/weights (3x3x256x512, 1.18m/1.18m params)
#       FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256 (--/294.91k params)
#         FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256/BatchNorm (--/0 params)
#         FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256/weights (3x3x128x256, 294.91k/294.91k params)
#       FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256 (--/294.91k params)
#         FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256/BatchNorm (--/0 params)
#         FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256/weights (3x3x128x256, 294.91k/294.91k params)
#       FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128 (--/73.73k params)
#         FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/BatchNorm (--/0 params)
#         FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/weights (3x3x64x128, 73.73k/73.73k params)
#
# ======================End of Report==========================
# 141 ops no flops stats due to incomplete shapes.
# Parsing Inputs...
# Incomplete shape.
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes          .*BatchNorm.*,.*Initializer.*,.*Regularizer.*,.*BiasAdd.*
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
# Incomplete shape.
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/13.72k flops)
#   MultipleGridAnchorGenerator/sub (2.17k/2.17k flops)
#   MultipleGridAnchorGenerator/mul_20 (2.17k/2.17k flops)
#   MultipleGridAnchorGenerator/mul_19 (2.17k/2.17k flops)
#   MultipleGridAnchorGenerator/mul_28 (1.20k/1.20k flops)
#   MultipleGridAnchorGenerator/mul_27 (1.20k/1.20k flops)
#   MultipleGridAnchorGenerator/sub_1 (1.20k/1.20k flops)
#   MultipleGridAnchorGenerator/mul_21 (1.08k/1.08k flops)
#   MultipleGridAnchorGenerator/mul_29 (600/600 flops)
#   MultipleGridAnchorGenerator/mul_35 (300/300 flops)
#   MultipleGridAnchorGenerator/mul_36 (300/300 flops)
#   MultipleGridAnchorGenerator/sub_2 (300/300 flops)
#   MultipleGridAnchorGenerator/mul_37 (150/150 flops)
#   MultipleGridAnchorGenerator/mul_43 (108/108 flops)
#   MultipleGridAnchorGenerator/sub_3 (108/108 flops)
#   MultipleGridAnchorGenerator/mul_44 (108/108 flops)
#   MultipleGridAnchorGenerator/mul_45 (54/54 flops)
#   MultipleGridAnchorGenerator/mul_51 (48/48 flops)
#   MultipleGridAnchorGenerator/sub_4 (48/48 flops)
#   MultipleGridAnchorGenerator/mul_52 (48/48 flops)
#   MultipleGridAnchorGenerator/mul_53 (24/24 flops)
#   MultipleGridAnchorGenerator/mul_17 (19/19 flops)
#   MultipleGridAnchorGenerator/mul_18 (19/19 flops)
#   MultipleGridAnchorGenerator/mul_60 (12/12 flops)
#   MultipleGridAnchorGenerator/mul_59 (12/12 flops)
#   MultipleGridAnchorGenerator/sub_5 (12/12 flops)
#   MultipleGridAnchorGenerator/mul_26 (10/10 flops)
#   MultipleGridAnchorGenerator/mul_25 (10/10 flops)
#   MultipleGridAnchorGenerator/mul_56 (6/6 flops)
#   MultipleGridAnchorGenerator/mul_46 (6/6 flops)
#   MultipleGridAnchorGenerator/mul_47 (6/6 flops)
#   MultipleGridAnchorGenerator/mul_48 (6/6 flops)
#   MultipleGridAnchorGenerator/mul_54 (6/6 flops)
#   MultipleGridAnchorGenerator/mul_55 (6/6 flops)
#   MultipleGridAnchorGenerator/truediv_17 (6/6 flops)
#   MultipleGridAnchorGenerator/mul_61 (6/6 flops)
#   MultipleGridAnchorGenerator/truediv_19 (6/6 flops)
#   MultipleGridAnchorGenerator/truediv_18 (6/6 flops)
#   MultipleGridAnchorGenerator/truediv_15 (6/6 flops)
#   MultipleGridAnchorGenerator/truediv_16 (6/6 flops)
#   MultipleGridAnchorGenerator/mul_40 (6/6 flops)
#   MultipleGridAnchorGenerator/mul_39 (6/6 flops)
#   MultipleGridAnchorGenerator/mul_38 (6/6 flops)
#   MultipleGridAnchorGenerator/mul_22 (6/6 flops)
#   MultipleGridAnchorGenerator/mul_32 (6/6 flops)
#   MultipleGridAnchorGenerator/mul_31 (6/6 flops)
#   MultipleGridAnchorGenerator/mul_30 (6/6 flops)
#   MultipleGridAnchorGenerator/mul_23 (6/6 flops)
#   MultipleGridAnchorGenerator/mul_24 (6/6 flops)
#   MultipleGridAnchorGenerator/mul_34 (5/5 flops)
#   MultipleGridAnchorGenerator/mul_33 (5/5 flops)
#   MultipleGridAnchorGenerator/mul_41 (3/3 flops)
#   MultipleGridAnchorGenerator/truediv_14 (3/3 flops)
#   MultipleGridAnchorGenerator/mul_14 (3/3 flops)
#   MultipleGridAnchorGenerator/mul_15 (3/3 flops)
#   MultipleGridAnchorGenerator/mul_16 (3/3 flops)
#   MultipleGridAnchorGenerator/mul_42 (3/3 flops)
#   MultipleGridAnchorGenerator/mul_50 (2/2 flops)
#   MultipleGridAnchorGenerator/mul_49 (2/2 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/sub_5 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/SortByField_1/Equal (1/1 flops)
#   MultipleGridAnchorGenerator/truediv_12 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/sub (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/sub_1 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/sub_2 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_9 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_8 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_7 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_6 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/sub_3 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/sub_4 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/sub_8 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/sub_9 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_5 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_4 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_3 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/sub_6 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_2 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/sub_7 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_1 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_19 (1/1 flops)
#   Preprocessor/map/while/Less_1 (1/1 flops)
#   Preprocessor/map/while/Less (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/ones/Less (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_9 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_8 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_7 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_6 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_5 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_4 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_3 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_2 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_18 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_17 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_16 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_15 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_14 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_13 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_12 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_11 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_10 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_1 (1/1 flops)
#   MultipleGridAnchorGenerator/mul_5 (1/1 flops)
#   MultipleGridAnchorGenerator/Minimum (1/1 flops)
#   MultipleGridAnchorGenerator/truediv_11 (1/1 flops)
#   MultipleGridAnchorGenerator/truediv_10 (1/1 flops)
#   MultipleGridAnchorGenerator/truediv_1 (1/1 flops)
#   MultipleGridAnchorGenerator/truediv (1/1 flops)
#   MultipleGridAnchorGenerator/mul_9 (1/1 flops)
#   MultipleGridAnchorGenerator/mul_8 (1/1 flops)
#   MultipleGridAnchorGenerator/mul_7 (1/1 flops)
#   MultipleGridAnchorGenerator/mul_6 (1/1 flops)
#   MultipleGridAnchorGenerator/mul_58 (1/1 flops)
#   MultipleGridAnchorGenerator/mul_57 (1/1 flops)
#   MultipleGridAnchorGenerator/truediv_13 (1/1 flops)
#   MultipleGridAnchorGenerator/mul_4 (1/1 flops)
#   MultipleGridAnchorGenerator/mul_3 (1/1 flops)
#   MultipleGridAnchorGenerator/mul_2 (1/1 flops)
#   MultipleGridAnchorGenerator/mul_13 (1/1 flops)
#   MultipleGridAnchorGenerator/mul_12 (1/1 flops)
#   MultipleGridAnchorGenerator/mul_11 (1/1 flops)
#   MultipleGridAnchorGenerator/mul_10 (1/1 flops)
#   MultipleGridAnchorGenerator/mul_1 (1/1 flops)
#   MultipleGridAnchorGenerator/mul (1/1 flops)
#   MultipleGridAnchorGenerator/assert_equal_1/Equal (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame/sub (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/Minimum_5 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/Minimum_4 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/Minimum_3 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/Minimum_2 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/Minimum_1 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/Minimum (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/Greater (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame/truediv_1 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame/truediv (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame/sub_1 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/SortByField/Equal (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/Less_1 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/Less (1/1 flops)
#   MultipleGridAnchorGenerator/truediv_9 (1/1 flops)
#   MultipleGridAnchorGenerator/truediv_8 (1/1 flops)
#   MultipleGridAnchorGenerator/truediv_7 (1/1 flops)
#   MultipleGridAnchorGenerator/truediv_6 (1/1 flops)
#   MultipleGridAnchorGenerator/truediv_5 (1/1 flops)
#   MultipleGridAnchorGenerator/truediv_4 (1/1 flops)
#   MultipleGridAnchorGenerator/truediv_3 (1/1 flops)
#   MultipleGridAnchorGenerator/truediv_2 (1/1 flops)
#
# ======================End of Report==========================
# 2020-08-25 18:04:13.784918: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-08-25 18:04:13.825070: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-25 18:04:13.825715: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-08-25 18:04:13.826059: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-08-25 18:04:13.828876: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-08-25 18:04:13.832189: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-08-25 18:04:13.833051: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-08-25 18:04:13.835614: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-08-25 18:04:13.846868: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-08-25 18:04:13.856242: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-08-25 18:04:13.856418: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-25 18:04:13.857098: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-25 18:04:13.857677: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-08-25 18:04:13.862166: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX512F
# 2020-08-25 18:04:13.867663: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2000115000 Hz
# 2020-08-25 18:04:13.867871: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2cb0f40 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-08-25 18:04:13.867901: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-08-25 18:04:13.981834: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-25 18:04:13.982596: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2cb12c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-08-25 18:04:13.982633: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2020-08-25 18:04:13.982847: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-25 18:04:13.983429: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-08-25 18:04:13.983501: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-08-25 18:04:13.983531: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-08-25 18:04:13.983555: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-08-25 18:04:13.983576: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-08-25 18:04:13.983599: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-08-25 18:04:13.983620: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-08-25 18:04:13.983642: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-08-25 18:04:13.983716: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-25 18:04:13.984322: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-25 18:04:13.984897: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-08-25 18:04:13.984962: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-08-25 18:04:13.986309: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-08-25 18:04:13.986339: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-08-25 18:04:13.986351: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-08-25 18:04:13.986488: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-25 18:04:13.987110: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-25 18:04:13.987706: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-08-25 18:04:13.987749: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14221 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# INFO:tensorflow:Restoring parameters from training/model.ckpt-80000
# I0825 18:04:13.989692 139811698919296 saver.py:1284] Restoring parameters from training/model.ckpt-80000
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/tools/freeze_graph.py:127: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# W0825 18:04:15.716165 139811698919296 deprecation.py:323] From /tensorflow-1.15.2/python3.6/tensorflow_core/python/tools/freeze_graph.py:127: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# 2020-08-25 18:04:16.285552: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-25 18:04:16.286187: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-08-25 18:04:16.286281: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-08-25 18:04:16.286308: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-08-25 18:04:16.286333: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-08-25 18:04:16.286401: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-08-25 18:04:16.286433: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-08-25 18:04:16.286456: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-08-25 18:04:16.286479: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-08-25 18:04:16.286572: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-25 18:04:16.287190: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-25 18:04:16.287826: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-08-25 18:04:16.287870: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-08-25 18:04:16.287889: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-08-25 18:04:16.287899: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-08-25 18:04:16.288009: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-25 18:04:16.288661: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-25 18:04:16.289249: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14221 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# INFO:tensorflow:Restoring parameters from training/model.ckpt-80000
# I0825 18:04:16.290520 139811698919296 saver.py:1284] Restoring parameters from training/model.ckpt-80000
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/tools/freeze_graph.py:233: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# W0825 18:04:16.956799 139811698919296 deprecation.py:323] From /tensorflow-1.15.2/python3.6/tensorflow_core/python/tools/freeze_graph.py:233: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/framework/graph_util_impl.py:277: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# W0825 18:04:16.957104 139811698919296 deprecation.py:323] From /tensorflow-1.15.2/python3.6/tensorflow_core/python/framework/graph_util_impl.py:277: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# INFO:tensorflow:Froze 324 variables.
# I0825 18:04:17.330993 139811698919296 graph_util_impl.py:334] Froze 324 variables.
# INFO:tensorflow:Converted 324 variables to const ops.
# I0825 18:04:17.408460 139811698919296 graph_util_impl.py:394] Converted 324 variables to const ops.
# 2020-08-25 18:04:17.560971: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-25 18:04:17.561624: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-08-25 18:04:17.561732: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-08-25 18:04:17.561763: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-08-25 18:04:17.561791: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-08-25 18:04:17.561818: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-08-25 18:04:17.561843: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-08-25 18:04:17.561869: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-08-25 18:04:17.561895: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-08-25 18:04:17.561992: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-25 18:04:17.562606: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-25 18:04:17.563166: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-08-25 18:04:17.563210: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-08-25 18:04:17.563225: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-08-25 18:04:17.563236: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-08-25 18:04:17.563340: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-25 18:04:17.563982: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-25 18:04:17.564551: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14221 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# WARNING:tensorflow:From /content/models/research/object_detection/exporter.py:384: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# W0825 18:04:18.124479 139811698919296 deprecation.py:323] From /content/models/research/object_detection/exporter.py:384: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# INFO:tensorflow:No assets to save.
# I0825 18:04:18.125215 139811698919296 builder_impl.py:640] No assets to save.
# INFO:tensorflow:No assets to write.
# I0825 18:04:18.125358 139811698919296 builder_impl.py:460] No assets to write.
# INFO:tensorflow:SavedModel written to: ./fine_tuned_model/saved_model/saved_model.pb
# I0825 18:04:18.393696 139811698919296 builder_impl.py:425] SavedModel written to: ./fine_tuned_model/saved_model/saved_model.pb
# INFO:tensorflow:Writing pipeline config file to ./fine_tuned_model/pipeline.config
# I0825 18:04:18.420169 139811698919296 config_util.py:254] Writing pipeline config file to ./fine_tuned_model/pipeline.config

# %%
# !ls {output_directory}
# Out:
# checkpoint			model.ckpt.index  saved_model
# frozen_inference_graph.pb	model.ckpt.meta
# model.ckpt.data-00000-of-00001	pipeline.config

# %% [markdown]
# ## Download the model `.pb` file

# %%
import os

pb_fname = os.path.join(os.path.abspath(output_directory), "frozen_inference_graph.pb")
assert os.path.isfile(pb_fname), '`{}` not exist'.format(pb_fname)

# %%
# !ls -alh {pb_fname}
# Out:
# -rw-r--r-- 1 root root 19M Aug 25 18:04 /content/models/research/fine_tuned_model/frozen_inference_graph.pb

# %% [markdown]
# ### Option1 : upload the `.pb` file to your Google Drive
# Then download it from your Google Drive to local file system.
#
# During this step, you will be prompted to enter the token.

# %%
# Install the PyDrive wrapper & import libraries.
# This only needs to be done once in a notebook.
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials


# Authenticate and create the PyDrive client.
# This only needs to be done once in a notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

fname = os.path.basename(pb_fname)
# Create & upload a text file.
uploaded = drive.CreateFile({'title': fname})
uploaded.SetContentFile(pb_fname)
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-98ef892868d4> in <module>()
#       1 # Install the PyDrive wrapper & import libraries.
#       2 # This only needs to be done once in a notebook.
# ----> 3 get_ipython().system('pip install -U -q PyDrive')
#       4 from pydrive.auth import GoogleAuth
#       5 from pydrive.drive import GoogleDrive
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#     100       kwargs.update({'also_return_output': True})
#     101
# --> 102     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     103
#     104     if pip_warn:
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     436   # stack.
#     437   result = _run_command(
# --> 438       shell.var_expand(cmd, depth=2), clear_streamed_output=False)
#     439   shell.user_ns['_exit_code'] = result.returncode
#     440   if -result.returncode in _INTERRUPTED_SIGNALS:
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _run_command(cmd, clear_streamed_output)
#     193       os.close(child_pty)
#     194
# --> 195       return _monitor_process(parent_pty, epoll, p, cmd, update_stdin_widget)
#     196   finally:
#     197     epoll.close()
#
# /usr/lib/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      86         if type is None:
#      87             try:
# ---> 88                 next(self.gen)
#      89             except StopIteration:
#      90                 return False
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _display_stdin_widget(delay_millis)
#     353
#     354   hide_args = ['cell_remove_stdin', {}]
# --> 355   _message.blocking_request(*hide_args, parent=shell.parent_header)
#     356
#     357
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     169   # unique.
#     170   request_id = send_request(request_type, request, parent=parent)
# --> 171   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#      99     reply = _read_next_input_message()
#     100     if reply == _NOT_READY or not isinstance(reply, dict):
# --> 101       time.sleep(0.025)
#     102       continue
#     103     if (reply.get('type') == 'colab_reply' and
#
# KeyboardInterrupt:

# %% [markdown]
# ### Option2 :  Download the `.pb` file directly to your local file system
# This method may not be stable when downloading large files like the model `.pb` file. Try **option 1** instead if not working.

# %%
from google.colab import files
files.download(pb_fname)

# %% [markdown]
# ### Download the `label_map.pbtxt` file

# %%
from google.colab import files
files.download(label_map_pbtxt_fname)

# %% [markdown]
# ### Download the modified pipline file
# If you plan to use OpenVINO toolkit to convert the `.pb` file to inference faster on Intel's hardware (CPU/GPU, Movidius, etc.)

# %%
files.download(pipeline_fname)

# %%
# !tar cfz fine_tuned_model.tar.gz fine_tuned_model
# from google.colab import files
# files.download('fine_tuned_model.tar.gz')

# %% [markdown]
# ## Run inference test
# Test with images in repository `object_detection_demo/test` directory.

# %%
import os
import glob

# Path to frozen detection graph. This is the actual model that is used for the object detection.
PATH_TO_CKPT = pb_fname

# List of the strings that is used to add correct label for each box.
PATH_TO_LABELS = label_map_pbtxt_fname

# If you want to test the code with your images, just add images files to the PATH_TO_TEST_IMAGES_DIR.
PATH_TO_TEST_IMAGES_DIR =  os.path.join(repo_dir_path, "test")

assert os.path.isfile(pb_fname)
assert os.path.isfile(PATH_TO_LABELS)
TEST_IMAGE_PATHS = glob.glob(os.path.join(PATH_TO_TEST_IMAGES_DIR, "*.*"))
assert len(TEST_IMAGE_PATHS) > 0, 'No image found in `{}`.'.format(PATH_TO_TEST_IMAGES_DIR)
print(TEST_IMAGE_PATHS)
# Out:
# ['/content/object_detection_demo/test/481.xml', '/content/object_detection_demo/test/474.xml', '/content/object_detection_demo/test/469.xml', '/content/object_detection_demo/test/470.jpg', '/content/object_detection_demo/test/467.jpg', '/content/object_detection_demo/test/462.xml', '/content/object_detection_demo/test/478.jpg', '/content/object_detection_demo/test/461.jpg', '/content/object_detection_demo/test/467.xml', '/content/object_detection_demo/test/474.jpg', '/content/object_detection_demo/test/469.jpg', '/content/object_detection_demo/test/472.jpg', '/content/object_detection_demo/test/468.jpg', '/content/object_detection_demo/test/473.jpg', '/content/object_detection_demo/test/462.jpg', '/content/object_detection_demo/test/475.xml', '/content/object_detection_demo/test/473.xml', '/content/object_detection_demo/test/472.xml', '/content/object_detection_demo/test/470.xml', '/content/object_detection_demo/test/468.xml', '/content/object_detection_demo/test/460.jpg', '/content/object_detection_demo/test/478.xml', '/content/object_detection_demo/test/481.jpg', '/content/object_detection_demo/test/460.xml', '/content/object_detection_demo/test/480.jpg', '/content/object_detection_demo/test/480.xml', '/content/object_detection_demo/test/475.jpg', '/content/object_detection_demo/test/461.xml']

# %%
# %cd /content/models/research/object_detection

import numpy as np
import os
import six.moves.urllib as urllib
import sys
import tarfile
import tensorflow as tf
import zipfile

from collections import defaultdict
from io import StringIO
from matplotlib import pyplot as plt
from PIL import Image

# This is needed since the notebook is stored in the object_detection folder.
sys.path.append("..")
from object_detection.utils import ops as utils_ops


# This is needed to display the images.
# %matplotlib inline


from object_detection.utils import label_map_util

from object_detection.utils import visualization_utils as vis_util


detection_graph = tf.Graph()
with detection_graph.as_default():
    od_graph_def = tf.GraphDef()
    with tf.gfile.GFile(PATH_TO_CKPT, 'rb') as fid:
        serialized_graph = fid.read()
        od_graph_def.ParseFromString(serialized_graph)
        tf.import_graph_def(od_graph_def, name='')


label_map = label_map_util.load_labelmap(PATH_TO_LABELS)
categories = label_map_util.convert_label_map_to_categories(
    label_map, max_num_classes=num_classes, use_display_name=True)
category_index = label_map_util.create_category_index(categories)


def load_image_into_numpy_array(image):
    (im_width, im_height) = image.size
    return np.array(image.getdata()).reshape(
        (im_height, im_width, 3)).astype(np.uint8)

# Size, in inches, of the output images.
IMAGE_SIZE = (12, 8)


def run_inference_for_single_image(image, graph):
    with graph.as_default():
        with tf.Session() as sess:
            # Get handles to input and output tensors
            ops = tf.get_default_graph().get_operations()
            all_tensor_names = {
                output.name for op in ops for output in op.outputs}
            tensor_dict = {}
            for key in [
                'num_detections', 'detection_boxes', 'detection_scores',
                'detection_classes', 'detection_masks'
            ]:
                tensor_name = key + ':0'
                if tensor_name in all_tensor_names:
                    tensor_dict[key] = tf.get_default_graph().get_tensor_by_name(
                        tensor_name)
            if 'detection_masks' in tensor_dict:
                # The following processing is only for single image
                detection_boxes = tf.squeeze(
                    tensor_dict['detection_boxes'], [0])
                detection_masks = tf.squeeze(
                    tensor_dict['detection_masks'], [0])
                # Reframe is required to translate mask from box coordinates to image coordinates and fit the image size.
                real_num_detection = tf.cast(
                    tensor_dict['num_detections'][0], tf.int32)
                detection_boxes = tf.slice(detection_boxes, [0, 0], [
                                           real_num_detection, -1])
                detection_masks = tf.slice(detection_masks, [0, 0, 0], [
                                           real_num_detection, -1, -1])
                detection_masks_reframed = utils_ops.reframe_box_masks_to_image_masks(
                    detection_masks, detection_boxes, image.shape[0], image.shape[1])
                detection_masks_reframed = tf.cast(
                    tf.greater(detection_masks_reframed, 0.5), tf.uint8)
                # Follow the convention by adding back the batch dimension
                tensor_dict['detection_masks'] = tf.expand_dims(
                    detection_masks_reframed, 0)
            image_tensor = tf.get_default_graph().get_tensor_by_name('image_tensor:0')

            # Run inference
            output_dict = sess.run(tensor_dict,
                                   feed_dict={image_tensor: np.expand_dims(image, 0)})

            # all outputs are float32 numpy arrays, so convert types as appropriate
            output_dict['num_detections'] = int(
                output_dict['num_detections'][0])
            output_dict['detection_classes'] = output_dict[
                'detection_classes'][0].astype(np.uint8)
            output_dict['detection_boxes'] = output_dict['detection_boxes'][0]
            output_dict['detection_scores'] = output_dict['detection_scores'][0]
            if 'detection_masks' in output_dict:
                output_dict['detection_masks'] = output_dict['detection_masks'][0]
    return output_dict


for image_path in TEST_IMAGE_PATHS:
    image = Image.open(image_path)
    # the array based representation of the image will be used later in order to prepare the
    # result image with boxes and labels on it.
    image_np = load_image_into_numpy_array(image)
    # Expand dimensions since the model expects images to have shape: [1, None, None, 3]
    image_np_expanded = np.expand_dims(image_np, axis=0)
    # Actual detection.
    output_dict = run_inference_for_single_image(image_np, detection_graph)
    # Visualization of the results of a detection.
    vis_util.visualize_boxes_and_labels_on_image_array(
        image_np,
        output_dict['detection_boxes'],
        output_dict['detection_classes'],
        output_dict['detection_scores'],
        category_index,
        instance_masks=output_dict.get('detection_masks'),
        use_normalized_coordinates=True,
        line_thickness=8)
    plt.figure(figsize=IMAGE_SIZE)
    plt.imshow(image_np)
# Out:
# /content/models/research/object_detection
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# <ipython-input-37-875014c81bc0> in <module>()
#     107
#     108 for image_path in TEST_IMAGE_PATHS:
# --> 109     image = Image.open(image_path)
#     110     # the array based representation of the image will be used later in order to prepare the
#     111     # result image with boxes and labels on it.
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in open(fp, mode)
#    2860         warnings.warn(message)
#    2861     raise UnidentifiedImageError(
# -> 2862         "cannot identify image file %r" % (filename if filename else fp)
#    2863     )
#    2864
#
# UnidentifiedImageError: cannot identify image file '/content/object_detection_demo/test/481.xml'
